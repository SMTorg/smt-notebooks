# %% [markdown]
# <a href="https://colab.research.google.com/github/SMTorg/smt-notebooks/blob/master/MFK/SMT_MFEGO.ipynb" target="_blank" rel="nofollow"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>

# %% [markdown]
# <div class="alert alert-info fade">
# <b>Multifidelity Notebook  -  Educational Bayesian Optimization  </b>
#
# Nathalie BARTOLI ONERA/DTIS/M2CI
#
# April 2026 `version SMT 2.13`
#
# </div>

# %% [markdown]
# <div class="jumbotron text-left"><b>
# This notebook describes how to use the MFEGO algorithm, which is a python toolbox for solving an optimization problem with multifidelity sources. This tutorial uses SMT toolbox with multifidelity data to build a surrogate model or perform a multifidelity  optimization.</b></div>
#
# Authors :
# - Nathalie BARTOLI ONERA/DTIS/M2CI
# - Thierry LEFEBVRE ONERA/DTIS/M2CI
#
# with contributions from
#
# - Mostafa Meliani former ISAE-SUPAERO student
# - Rémy Priem former ISAE-SUPAERO - ONERA PhD student
# - Alejandro Diaz Bolivar former ONERA student
# - Rémy Charayron current ISAE-SUPAERO - ONERA PhD student
# - Andres Lopez-Lopera - ONERA Post Doc

# %% [markdown]
# ## About SMT toolbox
# <div class="alert alert-info" id="d110">
# SMT is a joint library between NASA, UoM, ONERA and ISAE-SUPAERO. It offers many surrogate modeling tools with a focus on derivatives. Le Gratiet's formulation was implemented as part of SMT.
#
# To use SMT models, please follow this link : https://github.com/SMTorg/SMT/blob/master/README.md. The documentation is available here: http://smt.readthedocs.io/en/latest/
#
# </div>

# %% [markdown]
# ###### Objectives of the Lab session
# <div class="alert alert-success">
#
# <p> 1D given examples</p>
# <ol> -  build 1D surrogate models from 2 fidelity levels: mono and fidelity  </ol>
# <ol> -  optimize 1D function with 2 fidelity levels: mono and multifidelity in order to compare EGO and MFEGO  </ol>
#     A reference solution is obtained with a gradient based optimizer (SLSQP).
# <p> Proposed Exercices </p>
# <ol> -  approximate a 1D function with 3 fidelity levels: compare mono and multifidelity models </ol>
# <ol> -  optimize the 2D Branin function: compare EGO  and MFEGO   </ol>
# <ol> -  optional: optimize the 2D Rosenbrock function: compare EGO and MFEGO  </ol>
# </div>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
from IPython.display import Image

# %% [markdown]
# # Multi-Fidelity Kriging and Optimization
#
# We are interested in learning a high-fidelity function while using low-fidelity information sources to enhance the model, for that we use Le Gratiet recursive formulation of multi-fidelity Kriging.
#
# <p class="alert alert-warning" style="padding:1em">
# An important assumption by using this recursive formulation is the nested DOE.
# If we have two fidelity levels (HF and LF)
# $$X_{HF} \subset X_{LF}$$
#  </p>
#
# ### Kennedy O'Hagan/Le Gratiet recursive formulation:
# To perform Le Gratiet's learning, we first learn the lowest fidelity, then we consecutively learn the relationship between every two consecutive fidelity levels (scaling factor $\rho_{k-1}$ and discrepancy function $\delta_k(\cdot)$).
#
# $$\mu_{k} = \rho_{k-1}\;\mu_{k-1} + \mu_{\delta_k}\\
# \sigma^2_{k} = \rho_{k-1}^2\;\sigma^2_{k-1}+\sigma^2_{\delta_k}$$
#
#
#
#
# This generally results in a better surrogate model compared to training the high-fidelity alone.

# %%
Image(filename="co-krigeage.png")

# %% [markdown]
# ## 0. SMT Installation
# You need to install SMT library from: https://github.com/SMTorg/smt
# ###google colab
# !pip install smt
# ###or  directly on your computer
# import smt

# %%
# %pip install smt
import smt

print("SMT version", smt.__version__)
# Out:
# Requirement already satisfied: smt in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (2.13.0)
# Requirement already satisfied: packaging in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from smt) (25.0)
# Requirement already satisfied: scikit-learn in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from smt) (1.7.0)
# Requirement already satisfied: pyDOE3>=1.5.0 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from smt) (1.6.2)
# Requirement already satisfied: scipy in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from smt) (1.16.0)
# Requirement already satisfied: jenn<3.0,>=2.0.0 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from smt) (2.0.0)
# Requirement already satisfied: jsonpointer in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from jenn<3.0,>=2.0.0->smt) (3.0.0)
# Requirement already satisfied: jsonschema in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from jenn<3.0,>=2.0.0->smt) (4.24.0)
# Requirement already satisfied: orjson in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from jenn<3.0,>=2.0.0->smt) (3.11.0)
# Requirement already satisfied: numpy in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from jenn<3.0,>=2.0.0->smt) (2.4.4)
# Requirement already satisfied: matplotlib in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from jenn<3.0,>=2.0.0->smt) (3.10.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from jsonschema->jenn<3.0,>=2.0.0->smt) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from jsonschema->jenn<3.0,>=2.0.0->smt) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from jsonschema->jenn<3.0,>=2.0.0->smt) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from jsonschema->jenn<3.0,>=2.0.0->smt) (0.26.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from referencing>=0.28.4->jsonschema->jenn<3.0,>=2.0.0->smt) (4.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from matplotlib->jenn<3.0,>=2.0.0->smt) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from matplotlib->jenn<3.0,>=2.0.0->smt) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from matplotlib->jenn<3.0,>=2.0.0->smt) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from matplotlib->jenn<3.0,>=2.0.0->smt) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from matplotlib->jenn<3.0,>=2.0.0->smt) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from matplotlib->jenn<3.0,>=2.0.0->smt) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from matplotlib->jenn<3.0,>=2.0.0->smt) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from python-dateutil>=2.7->matplotlib->jenn<3.0,>=2.0.0->smt) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from scikit-learn->smt) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\bartoli\anaconda3\envs\myenvsmt\lib\site-packages (from scikit-learn->smt) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# SMT version 2.13.0

# %% [markdown]
# <p class="alert alert-warning" style="padding:1em">
# %matplotlib inline for  google colab instead of %matplotlib notebook
#   </p>

# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. RSM building

# %% [markdown]
# First let's study the operation of the co-kriging on a 1D test function
#
# Define the analytic function: *Forretal function*. the same function of Forretal LF as the one presented in the following article has been used
#
# >*A radial basis function-based multi-fidelity surrogate model: exploring correlation between high-fidelity and low-fidelity models.* Structural and Multidisciplinary Optimization. 01/04/2019. Xueguan Song, Liye Lv, Wei Sun, Jie Zhang. https://doi.org/10.1007/s00158-019-02248-0

# %%
# defining low and high fidelity functions
def LF_function(x):
    return 0.5 * ((x * 6 - 2) ** 2) * np.sin((x * 6 - 2) * 2) + (x - 0.5) * 10.0 - 5


def HF_function(x):
    return ((x * 6 - 2) ** 2) * np.sin((x * 6 - 2) * 2)

# %%
# To plot the 2 analytical functions
x = np.linspace(0, 1, 101, endpoint=True).reshape(-1, 1)
plt.figure()

plt.plot(x, HF_function(x), "b-", label="High Fidelity")
plt.plot(x, LF_function(x), "r--", label="Low Fidelity")

plt.legend(loc=0)
plt.ylim(-10, 17)
plt.xlim(-0.1, 1.1)
plt.xlabel(r"$x$")
plt.ylabel(r"$y$")
plt.show()

# %% [markdown]
# First we need to import nested DOE capability from SMT

# %%
from smt.applications.mfk import NestedLHS

# %% [markdown]
# Then let's create  a DOE suitable for multi fidelity

# %%
# Dimension
ndim = 1

#  Nested LHS sampling

xlimits = np.array([[0.0, 1.0]])
xdoes = NestedLHS(nlevel=2, xlimits=xlimits)
Xt_c, Xt_e = xdoes(4)

# Evaluate the HF and LF functions
yt_e = HF_function(Xt_e)
yt_c = LF_function(Xt_c)

# to plot the HF and LF functions
plt.plot(x, HF_function(x), c="b", label="High Fidelity")
plt.plot(x, LF_function(x), c="r", label="Low Fidelity")
plt.scatter(Xt_e, yt_e, marker="o", color="b", label="HF doe")
plt.scatter(Xt_c, yt_c, marker="o", color="r", label="LF doe")
plt.legend(loc=0)
plt.show()

# %% [markdown]
# ### 1.1 Mono fidelity operation

# %% [markdown]
# Let's create 2 mono fidelity RSM (here Kriging)

# %%
from smt.surrogate_models import KRG

# %%
# Surrogate for the LF function
sm_LF = KRG()
sm_LF.set_training_values(Xt_c, yt_c)
sm_LF.train()

# To plot the surrogate model
x = np.linspace(0, 1, 101, endpoint=True).reshape(-1, 1)
# query the outputs
y_LF = sm_LF.predict_values(x)
# Out:
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 8
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
#    Training - done. Time (sec):  0.0915196
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 101
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0000000
#
#    Prediction time/pt. (sec) :  0.0000000

# %%
# Surrogate for the HF function
sm_HF = KRG()
sm_HF.set_training_values(Xt_e, yt_e)
sm_HF.train()

x = np.linspace(0, 1, 101, endpoint=True).reshape(-1, 1)

# query the outputs
y_HF = sm_HF.predict_values(x)
# Out:
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 4
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
#    Training - done. Time (sec):  0.0653720
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 101
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0000000
#
#    Prediction time/pt. (sec) :  0.0000000

# %%
# plot the outputs: functions and associated surrogates
plt.plot(x, HF_function(x), color="b", label="reference HF")
plt.plot(x, y_HF, linestyle="-.", color="darkblue", label="mean_gp_HF")
plt.plot(x, LF_function(x), color="r", label="reference LF")
plt.plot(x, y_LF, linestyle="-.", color="orange", label="mean_gp_LF")
plt.scatter(Xt_e, yt_e, marker="o", color="b", label="HF doe")
plt.scatter(Xt_c, yt_c, marker="o", color="r", label="LF doe")

plt.legend(loc=0)
plt.ylim(-10, 17)
plt.xlim(-0.1, 1.1)
plt.xlabel(r"$x$")
plt.ylabel(r"$y$")
plt.show()

# %%
# Accessing the variance and derivative of the model
MSE_LF = sm_LF.predict_variances(x)
MSE_HF = sm_HF.predict_variances(x)

# %%
# plot the variance
plt.plot(x, HF_function(x), color="b", label="reference HF")
plt.fill_between(
    np.ravel(x),
    np.ravel(y_LF - 2 * np.sqrt(MSE_LF)),
    np.ravel(y_LF + 2 * np.sqrt(MSE_LF)),
    color="grey",
    label="Confidence Interval",
)
plt.fill_between(
    np.ravel(x),
    np.ravel(y_HF - 2 * np.sqrt(MSE_HF)),
    np.ravel(y_HF + 2 * np.sqrt(MSE_HF)),
    color="lightgrey",
    label="Confidence Interval",
)

plt.plot(x, y_HF, linestyle="-.", color="darkblue", label="mean_MF_gp")
plt.plot(x, y_LF, linestyle="-.", color="orange", label="mean_LF_gp")
plt.scatter(Xt_e, yt_e, marker="o", color="b", label="HF doe")
plt.scatter(Xt_c, yt_c, marker="o", color="r", label="LF doe")

plt.legend(loc=0)
plt.ylim(-10, 17)
plt.xlim(-0.1, 1.1)
plt.xlabel(r"$x$")
plt.ylabel(r"$y$")
plt.show()

# %% [markdown]
# ### 1.2 Multi fidelity operation

# %%
from smt.applications import MFK

# %%
# %% Build the MFK object
sm_MF = MFK()

# low-fidelity dataset names being integers from 0 to level-1
sm_MF.set_training_values(Xt_c, yt_c, name=0)
# high-fidelity dataset without name
sm_MF.set_training_values(Xt_e, yt_e)

# train the model
sm_MF.train()

# test training
x = np.linspace(0, 1, 101, endpoint=True).reshape(-1, 1)

# query the outputs
y_MF = sm_MF.predict_values(x)
# Out:
# ___________________________________________________________________________
#
#                                     MFK
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 4
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
#    Training - done. Time (sec):  0.1419227
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 101
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0000000
#
#    Prediction time/pt. (sec) :  0.0000000

# %%
# plot the outputs
plt.plot(x, HF_function(x), color="b", label="reference HF")
plt.plot(x, y_MF, linestyle="-.", color="black", label="mean_MF_gp")
plt.scatter(Xt_e, yt_e, marker="o", color="b", label="HF doe")
plt.scatter(Xt_c, yt_c, marker="o", color="r", label="LF doe")

plt.legend(loc=0)
plt.ylim(-10, 17)
plt.xlim(-0.1, 1.1)
plt.xlabel(r"$x$")
plt.ylabel(r"$y$")
plt.show()

# %%
# Accessing the variance and derivative of the model
MSE = sm_MF.predict_variances(x)

# %%
# plot the variance
plt.fill_between(
    np.ravel(x),
    np.ravel(y_MF - 2 * np.sqrt(MSE)),
    np.ravel(y_MF + 2 * np.sqrt(MSE)),
    color="grey",
    label="Confidence Interval",
)
plt.plot(x, y_MF, linestyle="-.", color="black", label="mean_MF_gp")
plt.scatter(Xt_e, yt_e, marker="o", color="b", label="HF doe")
plt.scatter(Xt_c, yt_c, marker="o", color="r", label="LF doe")

plt.legend(loc=0)
plt.ylim(-10, 17)
plt.xlim(-0.1, 1.1)
plt.xlabel(r"$x$")
plt.ylabel(r"$y$")
plt.show()

# %% [markdown]
# ## 1.3 Exercice with a 1D toy function  and 3 fidelity levels

# %%
## Exercice 1D with 3 levels
def LF_function(x):
    return 0.5 * ((x * 6 - 2) ** 2) * np.sin((x * 6 - 2) * 2) + (x - 0.5) * 10.0 - 5


def MF_function(x):
    return LF_function(x) + 3


def HF_function(x):
    return ((x * 6 - 2) ** 2) * np.sin((x * 6 - 2) * 2)


x = np.linspace(0, 1, 101, endpoint=True).reshape(-1, 1)

plt.figure()
plt.plot(x, HF_function(x), "--k", label="High Fidelity (HF)")
plt.plot(x, MF_function(x), "--b", label="High Fidelity (MF)")
plt.plot(x, LF_function(x), "--r", label="Low Fidelity (LF)")
plt.legend(loc=0)
plt.ylim(-10, 17)
plt.xlim(-0.1, 1.1)
plt.xlabel(r"$x$")
plt.ylabel(r"$y$")
plt.show()

# %% [markdown]
#  ### <font color='blue'>Exercice 1:  Create a nested DOE with 3 levels</font>

# %%
from smt.applications import MFK
import numpy as np
from matplotlib import pyplot as plt
from smt.surrogate_models import KRG
from smt.applications.mfk import NestedLHS


def LF_function(x):
    return 0.5 * ((x * 6 - 2) ** 2) * np.sin((x * 6 - 2) * 2) + (x - 0.5) * 10.0 - 5


def MF_function(x):
    return LF_function(x) + 3


def HF_function(x):
    return ((x * 6 - 2) ** 2) * np.sin((x * 6 - 2) * 2)


x = np.linspace(0, 1, 101, endpoint=True).reshape(-1, 1)

plt.figure()
plt.plot(x, HF_function(x), "--k", label="High Fidelity (HF)")
plt.plot(x, MF_function(x), "--b", label="High Fidelity (MF)")
plt.plot(x, LF_function(x), "--r", label="Low Fidelity (LF)")
plt.legend(loc=0)
plt.ylim(-10, 17)
plt.xlim(-0.1, 1.1)
plt.xlabel(r"$x$")
plt.ylabel(r"$y$")
plt.show()


# LHS sampling
ndim = 1
nlvl = 3

# Nested DOE
xlimits = np.array([[0.0, 1.0]])
xdoes = NestedLHS(nlevel=nlvl, xlimits=xlimits)
Xt_c, Xt_m, Xt_e = xdoes(3)

# Expensive DOE with 4 points = Xt_e
# Intermediate DOE with 8 points = Xt_m
# Cheap DOE with 16 points Xt_c


# Evaluate the HF and LF functions
yt_e = HF_function(Xt_e)
yt_m = MF_function(Xt_m)
yt_c = LF_function(Xt_c)


plt.plot(x, HF_function(x), "--C0", label="High Fidelity (HF)")
plt.plot(x, MF_function(x), "--C1", label="Medium Fidelity (MF)")
plt.plot(x, LF_function(x), "--C2", label="Low Fidelity (LF)")
plt.scatter(Xt_e, yt_e, marker="o", color="C0", label="HF doe")
plt.scatter(Xt_m, yt_m, marker="o", color="C1", label="MF doe")
plt.scatter(Xt_c, yt_c, marker="o", color="C2", label="LF doe")
plt.legend(loc=0)
plt.ylim(-10, 17)
plt.xlim(-0.1, 1.1)
plt.xlabel(r"$x$")
plt.ylabel(r"$y$")
plt.show()


# %% Build the MFK object with 3 levels
sm = MFK()

# low-fidelity dataset names being integers from 0 to level-1
sm.set_training_values(Xt_c, yt_c, name=0)
sm.set_training_values(Xt_m, yt_m, name=1)
# high-fidelity dataset without name
sm.set_training_values(Xt_e, yt_e)
# train the model
sm.train()

# test training
ntest = 101
nlvl = len(sm.X)
x = np.linspace(0, 1, ntest, endpoint=True).reshape(-1, 1)
# query the outputs
y = sm.predict_values(x)
y0 = sm._predict_intermediate_values(x, 1)
y1 = sm._predict_intermediate_values(x, 2)
var = sm.predict_variances(x)
varAll, _ = sm.predict_variances_all_levels(x)
var0 = varAll[:, 0].reshape(-1, 1)
var1 = varAll[:, 1].reshape(-1, 1)

plt.plot(x, HF_function(x), "--C0", label="High Fidelity (HF)")
plt.plot(x, MF_function(x), "--C1", label="Medium Fidelity (MF)")
plt.plot(x, LF_function(x), "--C2", label="Low Fidelity (LF)")
plt.plot(x, y, "C0", label="MFGP - HF")
plt.fill_between(
    np.ravel(x),
    np.ravel(y - 3 * np.sqrt(var)),
    np.ravel(y + 3 * np.sqrt(var)),
    color="C0",
    alpha=0.2,
)  # ,label ='Confidence Interval 99% HF')
plt.plot(x, y1, "C1", label="MFGP - MF")
plt.fill_between(
    np.ravel(x),
    np.ravel(y1 - 3 * np.sqrt(var1)),
    np.ravel(y1 + 3 * np.sqrt(var1)),
    color="C1",
    alpha=0.2,
)  # ,label ='Confidence Interval 99% MF')
plt.plot(x, y0, "C2", label="MFGP - LF")
plt.fill_between(
    np.ravel(x),
    np.ravel(y0 - 3 * np.sqrt(var0)),
    np.ravel(y0 + 3 * np.sqrt(var0)),
    color="C2",
    alpha=0.2,
)  # ,label ='Confidence Interval 99% LF')
plt.scatter(Xt_e, yt_e, marker="o", color="C0")  # , label='HF doe')
plt.scatter(Xt_m, yt_m, marker="o", color="C1")  # , label='MF doe')
plt.scatter(Xt_c, yt_c, marker="o", color="C2")  # , label='LF doe')
plt.legend(bbox_to_anchor=(1.65, 1.0))
plt.ylim(-10, 17)
plt.xlim(-0.1, 1.1)
plt.xlabel(r"$x$")
plt.ylabel(r"$y$")
plt.show()
# Out:
# ___________________________________________________________________________
#
#                                     MFK
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 3
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
#    Training - done. Time (sec):  0.2336197
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 101
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0000000
#
#    Prediction time/pt. (sec) :  0.0000000

# %% [markdown]
# ## 2- Optimization
# ### Surrogate-based optimization - Bayesian optimization

# %% [markdown]
# ### 2.1 EGO and SBO (mono fidelity)

# %% [markdown]
# Bayesian optimization is defined by Jonas Mockus in (Mockus, 1975) as an optimization technique based upon the minimization of the expected deviation from the extremum of the studied function.
#
# The objective function is treated as a black-box function. A Bayesian strategy sees the objective as a random function and places a prior over it. The prior captures our beliefs about the behavior of the function. After gathering the function evaluations, which are treated as data, the prior is updated to form the posterior distribution over the objective function. The posterior distribution, in turn, is used to construct an acquisition function (often also referred to as infill sampling criterion) that determines what the next query point should be.
#
# One of the earliest bodies of work on Bayesian optimisation that we are aware of is (Kushner, 1962 ; Kushner, 1964). Kushner used Wiener processes for one-dimensional problems. Kushner’s decision model was based on maximizing the probability of improvement, and included a parameter that controlled the trade-off between ‘more global’ and ‘more local’ optimization, in the same spirit as the Exploration/Exploitation trade-off.
#
# Meanwhile, in the former Soviet Union, Mockus and colleagues developed a multidimensional Bayesian optimization method using linear combinations of Wiener fields, some of which was published in English in (Mockus, 1975). This paper also describes an acquisition function that is based on myopic expected improvement of the posterior, which has been widely adopted in Bayesian optimization as the Expected Improvement function.
#
# In 1998, Jones used Gaussian processes together with the expected improvement function to successfully perform derivative-free optimization and experimental design through an algorithm called  Efficient  Global  Optimization, or EGO (Jones, 1998).
#
# ## Efficient Global Optimization
#
# In what follows, we describe the Efficient Global Optimization (EGO) algorithm, as published in (Jones, 1998).
#
# Let $F$ be an expensive black-box function to be minimized. We sample $F$ at the different locations  $X = \{x_1, x_2,\ldots,x_n\}$ yielding the responses $Y = \{y_1, y_2,\ldots,y_n\}$. We build a Kriging model (also called Gaussian process) with a mean function $\mu$ and a variance function $\sigma^{2}$.
#
# The next step is to compute the criterion EI. To do this, let us denote:
# $$f_{min} = \min \{y_1, y_2,\ldots,y_n\}.$$
# The Expected Improvement funtion (EI) can be expressed:
# $$E[I(x)] = E[\max(f_{min}-Y, 0)],$$
# where $Y$ is the random variable following the distribution $\mathcal{N}(\mu(x), \sigma^{2}(x))$.
# By expressing the right-hand side of EI expression as an integral, and applying some tedious integration by parts, one can express the expected improvement in closed form:
# $$
# E[I(x)] = (f_{min} - \mu(x))\Phi\left(\frac{f_{min} - \mu(x)}{\sigma(x)}\right) + \sigma(x) \phi\left(\frac{f_{min} - \mu(x)}{\sigma(x)}\right)
# $$
# where $\Phi(\cdot)$ and $\phi(\cdot)$ are respectively the cumulative and probability density functions of $\mathcal{N}(0,1)$.
#
# Next, we determine our next sampling point as :
# \begin{align}
# x_{n+1} = \arg \max_{x} \left(E[I(x)]\right)
# \end{align}
#
# We then test the response $y_{n+1}$ of our black-box function $F$ at $x_{n+1}$, rebuild the model taking into account the new information gained, and research the point of maximum expected improvement again.
#
# We summarize here the EGO algorithm:
#
# EGO(F, $n_{iter}$) \# Find the best minimum of $\operatorname{F}$ in $n_{iter}$ iterations
# For ($i=0:n_{iter}$)
#
# * $mod = {model}(X, Y)$  \# surrogate model based on sample vectors $X$ and $Y$
# * $f_{min} = \min Y$
# * $x_{i+1} = \arg \max {EI}(mod, f_{min})$ \# choose $x$ that maximizes EI
# * $y_{i+1} = {F}(x_{i+1})$ \# Probe the function at most promising point $x_{i+1}$
# * $X = [X,x_{i+1}]$
# * $Y = [Y,y_{i+1}]$
# * $i = i+1$
#
# $f_{min} = \min Y$
# Return : $f_{min}$ \# This is the best known solution after $n_{iter}$ iterations

# %% [markdown]
# Now we want to optimize a function  using Bayesian Optimization and comparing
# - Surrogate based optimization (SBO)
# - Expected improvement criterion (EI)

# %% [markdown]
# In a first step we compute the EI criterion

# %%
import scipy as sp
from scipy.stats import norm
from scipy.optimize import minimize


def EI(model, points, f_min):
    pred = model.predict_values(points)
    var = model.predict_variances(points)
    args0 = (f_min - pred) / var
    args1 = (f_min - pred) * norm.cdf(args0)
    args2 = var * norm.pdf(args0)

    if var.size == 1 and var == 0.0:  # can be use only if one point is computed
        return 0.0

    ei = args1 + args2
    return ei


# to plot the surrogate
x = np.linspace(0, 1, 101, endpoint=True).reshape(-1, 1)
#
Y_HF_mean = sm_HF.predict_values(x)
Y_HF_var = sm_HF.predict_variances(x)

# EI prediction
Y_EI = EI(sm_HF, x, np.min(yt_e))


# Plotting the results
fig = plt.figure()
ax = fig.add_subplot(111)
(true_fun,) = ax.plot(x, HF_function(x))
(data,) = ax.plot(Xt_e, yt_e, linestyle="", marker="o")
(gp,) = ax.plot(x, Y_HF_mean, linestyle="--", color="g")

un_gp = ax.fill_between(
    np.ravel(x),
    np.ravel(Y_HF_mean - 2 * np.sqrt(Y_HF_var)),
    np.ravel(Y_HF_mean + 2 * np.sqrt(Y_HF_var)),
    alpha=0.3,
    color="g",
)
ax1 = ax.twinx()

(ei,) = ax1.plot(x, Y_EI, color="red")

lines = [true_fun, data, gp, un_gp, ei]
ax.set_title("HF function")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax1.set_ylabel("EI")
fig.legend(
    lines,
    [
        "True function",
        "Data",
        "GPR prediction",
        "99 % confidence",
        "Expected Improvement",
    ],
    loc=[0.13, 0.64],
)
plt.show()
# Out:
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 101
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0009999
#
#    Prediction time/pt. (sec) :  0.0000099
#
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 101
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0000000
#
#    Prediction time/pt. (sec) :  0.0000000

# %% [markdown]
# Now we compute the EGO method and compare it to other infill criteria
# - SBO (surrogate based optimization): directly using the prediction of the surrogate model ($\mu$)
# - EI for expected Improvement (EGO)

# %%
# surrogate Based optimization: min the Surrogate model by using the mean value mu
def SBO(GP, point):
    res = GP.predict(point)
    return res

# %% [markdown]
# Choose the criterion: SBO or EI

# %%
IC = "EI"  # or 'SBO'

# %% [markdown]
# We need to find the reference value for optimum  (`SLSQP` algorithm is used from scipy).

# %%
x_start = np.atleast_2d(np.random.rand(20)).T

opt_all = np.array(
    [
        minimize(lambda x: float(HF_function(x)), x_st, method="SLSQP", bounds=[(0, 1)])
        for x_st in x_start
    ]
)

opt_success = opt_all[[opt_i["success"] for opt_i in opt_all]]
obj_success = np.array([opt_i["fun"] for opt_i in opt_success])
ind_min = np.argmin(obj_success)
opt = opt_success[ind_min]
x_et_k = opt["x"]
print(
    "A local optimal point is found in "
    + str(opt["x"])
    + " with the value "
    + str(opt["fun"])
)
print("A SLSQP algorithm from scipy has been used.")

sol_1D = opt["fun"]
# Out:
# A local optimal point is found in [0.75724742] with the value -6.020740054810583
# A SLSQP algorithm from scipy has been used.

# %%
import matplotlib.image as mpimg
import matplotlib.animation as animation
from IPython.display import HTML

# %% [markdown]
# Let's apply EGO algorithm and visualize the process

# %%
plt.ioff()

x_data = np.atleast_2d([0, 0.4, 0.9]).T
y_data = HF_function(x_data)
n_iter = 20
sm = KRG(theta0=[1e-2], print_global=False)

# accuracy
k = 0
eps = 1
threshold_accuracy = 1e-3

while eps >= threshold_accuracy and k < n_iter:
    x_start = np.atleast_2d(np.random.rand(20)).T
    f_min_k = np.min(y_data)
    sm.set_training_values(x_data, y_data)
    sm.train()

    if IC == "EI":

        def obj_k(x):
            return -EI(sm, np.atleast_2d(x), f_min_k)  # EI to maximize
    elif IC == "SBO":

        def obj_k(x):
            return SBO(sm, np.atleast_2d(x))  # SBO to minimize

    opt_all = np.array(
        [
            minimize(lambda x: float(obj_k(x)), x_st, method="SLSQP", bounds=[(0, 1)])
            for x_st in x_start
        ]
    )

    opt_success = opt_all[[opt_i["success"] for opt_i in opt_all]]
    obj_success = np.array([opt_i["fun"] for opt_i in opt_success])
    ind_min = np.argmin(obj_success)
    opt = opt_success[ind_min]
    x_et_k = opt["x"]

    y_et_k = HF_function(x_et_k)

    y_data = np.atleast_2d(np.append(y_data, y_et_k)).T
    x_data = np.atleast_2d(np.append(x_data, x_et_k)).T

    Y_GP_plot_mean = sm.predict_values(x)
    Y_GP_plot_var = sm.predict_variances(x)
    Y_EI_plot = obj_k(x)

    fig = plt.figure(figsize=[10, 10])
    ax = fig.add_subplot(111)
    if IC == "SBO":
        (ei,) = ax.plot(x, Y_EI_plot, color="red")
    else:
        ax1 = ax.twinx()
        (ei,) = ax1.plot(x, Y_EI_plot, color="red")
    (true_fun,) = ax.plot(x, HF_function(x))
    (data,) = ax.plot(
        x_data[0 : k + 3], y_data[0 : k + 3], linestyle="", marker="o", color="orange"
    )
    (opt,) = ax.plot(x_data[k + 3], y_data[k + 3], linestyle="", marker="*", color="r")
    (gp,) = ax.plot(x, Y_GP_plot_mean, linestyle="--", color="g")
    un_gp = ax.fill_between(
        np.ravel(x),
        np.ravel(Y_GP_plot_mean - 2 * np.sqrt(Y_GP_plot_var)),
        np.ravel(Y_GP_plot_mean + 2 * np.sqrt(Y_GP_plot_var)),
        alpha=0.3,
        color="g",
    )
    lines = [true_fun, data, gp, un_gp, opt, ei]
    ax.set_title("HF - function")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.legend(
        lines,
        [
            "True function",
            "Data",
            "GPR prediction",
            "99 % confidence",
            "Next point to Evaluate",
            "Infill Criteria",
        ],
    )
    plt.savefig("Optimization%d" % k)
    plt.close(fig)
    k = k + 1
    ind_best_current = np.argmin(y_data)
    y_opt_current = y_data[ind_best_current]
    eps = np.abs(y_opt_current - sol_1D)
ind_best = np.argmin(y_data)
x_opt = x_data[ind_best]
y_opt = y_data[ind_best]

print("Results : X = %s, Y = %s" % (x_opt, y_opt))
print("obtained in :", k, " iterations")
print("with accuracy of :", eps)
print(
    "Xopt test 1D ",
    x_opt,
    "with Yopt value=",
    y_opt,
    " obtained using EGO criterion = ",
    IC,
)
print(
    "Check if the optimal point is closed to the reference solution Xopt= (array([0.75724809]), array([-6.020740])"
)
print("---------------------------")

fig = plt.figure(figsize=[10, 10])

ax = plt.gca()
ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)

ims = []
for i in range(k):
    image_pt = mpimg.imread("Optimization%d.png" % i)
    im = plt.imshow(image_pt)
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=500)
HTML(ani.to_jshtml())
# Out:
# Results : X = [0.75683485], Y = [-6.02064868]
# obtained in : 9  iterations
# with accuracy of : [9.13764702e-05]
# Xopt test 1D  [0.75683485] with Yopt value= [-6.02064868]  obtained using EGO criterion =  EI
# Check if the optimal point is closed to the reference solution Xopt= (array([0.75724809]), array([-6.020740])
# ---------------------------
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img84ecf9bf1ea047ff98ea9d55cbc385a1">
#   <div class="anim-controls">
#     <input id="_anim_slider84ecf9bf1ea047ff98ea9d55cbc385a1" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim84ecf9bf1ea047ff98ea9d55cbc385a1.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim84ecf9bf1ea047ff98ea9d55cbc385a1.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim84ecf9bf1ea047ff98ea9d55cbc385a1.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim84ecf9bf1ea047ff98ea9d55cbc385a1.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim84ecf9bf1ea047ff98ea9d55cbc385a1.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim84ecf9bf1ea047ff98ea9d55cbc385a1.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim84ecf9bf1ea047ff98ea9d55cbc385a1.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim84ecf9bf1ea047ff98ea9d55cbc385a1.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim84ecf9bf1ea047ff98ea9d55cbc385a1.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim84ecf9bf1ea047ff98ea9d55cbc385a1.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select84ecf9bf1ea047ff98ea9d55cbc385a1"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_84ecf9bf1ea047ff98ea9d55cbc385a1"
#              >
#       <label for="_anim_radio1_84ecf9bf1ea047ff98ea9d55cbc385a1">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_84ecf9bf1ea047ff98ea9d55cbc385a1"
#              checked>
#       <label for="_anim_radio2_84ecf9bf1ea047ff98ea9d55cbc385a1">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_84ecf9bf1ea047ff98ea9d55cbc385a1"
#              >
#       <label for="_anim_radio3_84ecf9bf1ea047ff98ea9d55cbc385a1">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img84ecf9bf1ea047ff98ea9d55cbc385a1";
#     var slider_id = "_anim_slider84ecf9bf1ea047ff98ea9d55cbc385a1";
#     var loop_select_id = "_anim_loop_select84ecf9bf1ea047ff98ea9d55cbc385a1";
#     var frames = new Array(9);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjMsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvZiW1igAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQABAABJRE

# %% [markdown]
# ### We can now create a EGO class to be applied to other functions

# %%
class EGO:
    def __init__(self, function, kriging_model, bounds, sol, multi_start=20, eps=1e-3):
        self.km = kriging_model
        self.bounds = bounds
        self.function = function
        self.doe_x = self.km.training_points[None][0][0]
        self.doe_y = self.km.training_points[None][0][1]
        self.dim = self.km.nx
        self.corr_fun = self.km.options["corr"]
        self.multi_start = multi_start
        self.y0_best = np.min(self.doe_y)
        self.sol = sol
        self.eps = eps

    def compute_EI(self, x):
        # compute expected improvement at point x
        x = np.atleast_2d(x)
        Y_min = np.min(self.km.training_points[None][0][1])
        y_pred = self.km.predict_values(x)
        mse = self.km.predict_variances(x)
        y_pred = np.atleast_2d(y_pred)
        sigma_y = np.sqrt(mse)
        y_normed = (Y_min - y_pred[:, 0]) / sigma_y
        EI = (Y_min - y_pred[:, 0]) * sp.stats.norm.cdf(
            y_normed
        ) + sigma_y * sp.stats.norm.pdf(y_normed)
        return -np.ravel(EI)

    def run(self, budget):
        self.current_cost = 0
        n_iter = 0
        epsilon = 1
        doe_init_size_HF = len(self.doe_y)
        while self.current_cost < budget and epsilon >= self.eps:
            n_iter = n_iter + 1
            # optimization of the EI
            candidat = []
            value = []
            X0 = np.random.rand(self.multi_start, self.dim)
            for i in range(len(self.bounds)):
                X0[:, i] = (
                    X0[:, i] * (-self.bounds[i, 0] + self.bounds[i, 1])
                    + self.bounds[i, 0]
                )
            # Multi start
            for x in X0:
                new_point = sp.optimize.fmin_slsqp(
                    self.compute_EI, np.atleast_2d(x), bounds=self.bounds, iprint=0
                )
                candidat.append(new_point)
                value.append(self.compute_EI(new_point))
            value = np.array(value)

            ind_min = value.argmin()
            x_n = candidat[ind_min].reshape((1, self.dim))

            # Evaluation of the true function(s)
            y_n = self.function(x_n)
            y_n = np.atleast_2d(y_n)

            # updating the kriging meta-model
            self.doe_x = np.append(self.doe_x, x_n, axis=0)
            self.doe_y = np.append(self.doe_y, y_n, axis=0)
            self.km.set_training_values(self.doe_x, self.doe_y)
            # retraining the model
            self.km.train()
            # distance criterion
            epsilon = np.abs(np.min(self.doe_y) - self.sol)
            print("######################################")
            print("Iteration n=", n_iter)
            print(
                "Number of Hi Fi calls during optimization= ",
                len(self.doe_y) - doe_init_size_HF,
            )

            print("max EI found at x=", x_n)
            print(
                "Current best value=",
                np.min(self.doe_y),
                " distance to reference solution: ",
                epsilon,
            )
            print("Value of the EI =", value.min())
            self.current_cost = self.current_cost + 1
            # add total budget + dif 1D/1D

        Y_min = np.min(self.doe_y)
        return Y_min, self.km, self.doe_x, self.doe_y

# %% [markdown]
# Let's try it on the analytical function.

# %%
from smt.sampling_methods import LHS

# %%
dim = 1
n = 3  # number of high fidelity points (number of low fi is twice)
nlevel = 2
ub0 = 1.0
lb0 = 0.0

xlimits = np.array([[lb0, ub0]])

xdoes = LHS(xlimits=xlimits)
Xe = xdoes(n)
ye = HF_function(Xe)

sm = KRG(print_global=False)
sm.set_training_values(Xe, ye)
sm.train()

algo_EGO = EGO(HF_function, sm, bounds=xlimits, sol=sol_1D)
# Running the EGO algorithm for n_iter
budget = 10
Y_min, sm, doe_x, doe_y = algo_EGO.run(budget)
# Out:
# ######################################
# Iteration n= 1
# Number of Hi Fi calls during optimization=  1
# max EI found at x= [[0.87936316]]
# Current best value= -2.5147394837903327  distance to reference solution:  3.50600057102025
# Value of the EI = -0.2068500639913029
# ######################################
# Iteration n= 2
# Number of Hi Fi calls during optimization=  2
# max EI found at x= [[0.79351233]]
# Current best value= -5.257742349930787  distance to reference solution:  0.7629977048797958
# Value of the EI = -1.7545258809205324
# ######################################
# Iteration n= 3
# Number of Hi Fi calls during optimization=  3
# max EI found at x= [[0.74720198]]
# Current best value= -5.9684406851768435  distance to reference solution:  0.05229936963373927
# Value of the EI = -0.2040786578366186
# ######################################
# Iteration n= 4
# Number of Hi Fi calls during optimization=  4
# max EI found at x= [[0.67170493]]
# Current best value= -5.9684406851768435  distance to reference solution:  0.05229936963373927
# Value of the EI = -0.36176212771147676
# ######################################
# Iteration n= 5
# Number of Hi Fi calls during optimization=  5
# max EI found at x= [[0.]]
# Current best value= -5.9684406851768435  distance to reference solution:  0.05229936963373927
# Value of the EI = -0.8837739854493691
# ######################################
# Iteration n= 6
# Number of Hi Fi calls during optimization=  6
# max EI found at x= [[0.30053809]]
# Current best value= -5.9684406851768435  distance to reference solution:  0.05229936963373927
# Value of the EI = -0.09932171244071447
# ######################################
# Iteration n= 7
# Number of Hi Fi calls during optimization=  7
# max EI found at x= [[0.75732008]]
# Current best value= -6.020737338870048  distance to reference solution:  2.7159405346921517e-06
# Value of the EI = -0.053461117612288334

# %%
print("EGO results: ")
print("Total number of Hi Fi computations (including DOE): ", len(doe_y))
# Out:
# EGO results:
# Total number of Hi Fi computations (including DOE):  10

# %% [markdown]
# <div class="alert alert-info">
#     SMT toolbox also provides EGO algorithm
# (see https://smt.readthedocs.io/en/latest/_src_docs/applications/ego.html).  You could apply it to the analytical function.
# </div>

# %%
from smt.applications import EGO as EGO_SMT
from smt.design_space import DesignSpace

n_iter = 10
xlimits = np.array([[0.0, 1.0]])
xdoes = LHS(xlimits=xlimits)
xdoe = xdoes(n)
n_doe = xdoe.size

criterion = "EI"  #'EI' or 'SBO' or 'LCB'
design_space = DesignSpace(xlimits)
ego = EGO_SMT(
    n_iter=n_iter,
    criterion=criterion,
    xdoe=xdoe,
    surrogate=KRG(design_space=design_space, print_global=False),
)

x_opt, y_opt, _, x_data, y_data = ego.optimize(fun=HF_function)
print("Minimum in x={:.3f} with f(x)={:.3f}".format(float(x_opt), float(y_opt)))

x_plot = np.atleast_2d(np.linspace(0, 1, 100)).T
y_plot = HF_function(x_plot)

fig = plt.figure(figsize=[10, 10])
for i in range(n_iter):
    k = n_doe + i
    x_data_k = x_data[0:k]
    y_data_k = y_data[0:k]
    ego.gpr.set_training_values(x_data_k, y_data_k)
    ego.gpr.train()

    y_gp_plot = ego.gpr.predict_values(x_plot)
    y_gp_plot_var = ego.gpr.predict_variances(x_plot)
    y_ei_plot = -ego.EI(x_plot)

    ax = fig.add_subplot((n_iter + 1) // 2, 2, i + 1)
    ax1 = ax.twinx()
    (ei,) = ax1.plot(x_plot, y_ei_plot, color="red")

    (true_fun,) = ax.plot(x_plot, y_plot)
    (data,) = ax.plot(x_data_k, y_data_k, linestyle="", marker="o", color="orange")
    if i < n_iter - 1:
        (opt,) = ax.plot(x_data[k], y_data[k], linestyle="", marker="*", color="r")
    (gp,) = ax.plot(x_plot, y_gp_plot, linestyle="--", color="g")
    sig_plus = y_gp_plot + 3 * np.sqrt(y_gp_plot_var)
    sig_moins = y_gp_plot - 3 * np.sqrt(y_gp_plot_var)
    un_gp = ax.fill_between(
        x_plot.T[0], sig_plus.T[0], sig_moins.T[0], alpha=0.3, color="g"
    )
    lines = [true_fun, data, gp, un_gp, opt, ei]
    fig.suptitle("EGO optimization of $f(x) = HF function$")
    fig.subplots_adjust(hspace=0.4, wspace=0.4, top=0.8)
    ax.set_title("iteration {}".format(i + 1))
    fig.legend(
        lines,
        [
            "f(x)=HF_function(x)",
            "Given data points",
            "Kriging prediction",
            "Kriging 99% confidence interval",
            "Next point to evaluate",
            "Expected improvment function",
        ],
    )
plt.show()
# Out:
# Minimum in x=0.757 with f(x)=-6.021

# %% [markdown]
# ### 2.2 MFEGO (multi fidelity)

# %% [markdown]
# #### MFEGO:
#
# MFEGO is a two-step decision process:
# 1. fix most promising point: EI criterion
# 2. choose levels of enrichment: trade-off information gain/cost
#
# By using low-fidelity to reduce the uncertainty we reduce the Exploration contribution to the EI criterion. High-fidelity is used for Exploitation and model enhancement
#
# We compute the uncertainty reduction as:
# \begin{equation*}
# \sigma_{red}^{2}(k,x^*) = \sum_{i=0}^k \sigma_{\delta,i}^{2}(x^*) \prod_{j=i}^{l-1} \rho^2_j
# \end{equation*}

# %%
def ME(lvl, sigma_delta, sigma_rho, theta_vol_lvl, costs, last_val=0):
    """
    ME : Model enhancement criterion
    """

    MSE_r = last_val + sigma_delta[lvl] * np.prod(sigma_rho[lvl:]) * theta_vol_lvl[lvl]
    if last_val == 0:
        return True, MSE_r

    return np.log(MSE_r) - np.log(last_val) > 2.0 * np.log(
        1 + costs[lvl] / costs[lvl - 1]
    ), MSE_r

# %%
class MFEGO:
    """
    Attributes :
        functions, functions from lowest to highest level
    """

    def __init__(
        self, functions, kriging_model, bounds, costs, sol, multi_start=20, eps=1e-3
    ):
        self.km = kriging_model
        self.bounds = bounds
        self.n_lvls = 2
        if self.n_lvls != len(functions):
            raise Exception(
                "There must be as many functions as fidelity levels in your Kriging model"
            )
        if self.n_lvls != len(costs):
            raise Exception(
                "There must be as many costs as fidelity levels in your Kriging model"
            )

        self.levels = [0, None]  ## Highest level has the name None for smt
        self.functions = {0: functions[0], None: functions[1]}
        self.doe_x = {
            0: self.km.training_points[0][0][0],
            None: self.km.training_points[None][0][0],
        }
        self.doe_y = {
            0: self.km.training_points[0][0][1],
            None: self.km.training_points[None][0][1],
        }
        self.dim = self.km.nx
        self.costs = np.array(costs) + 0.0
        self.gain = []
        self.cost_hist = []
        self.corr_fun = self.km.options["corr"]
        self.multi_start = multi_start
        self.y0_best = np.min(self.doe_y[None])
        self.sol = sol
        self.eps = eps

    def cost_increment(self, lvls_added):
        # computing the cost increment after each iteration
        # lvls_added list of booleans, True if to be added, False otherwise
        return np.sum(lvls_added * self.costs) / self.costs[-1]

    def compute_EI(self, x):
        # compute expected improvement at point x
        x = np.atleast_2d(x)
        Y_min = np.min(self.km.training_points[None][0][1])
        y_pred = self.km.predict_values(x)
        mse = self.km.predict_variances(x)
        y_pred = np.atleast_2d(y_pred)
        sigma_y = np.sqrt(mse)
        y_normed = (Y_min - y_pred[:, 0]) / sigma_y
        EI = (Y_min - y_pred[:, 0]) * sp.stats.norm.cdf(
            y_normed
        ) + sigma_y * sp.stats.norm.pdf(y_normed)

        return -np.ravel(EI)

    def add_level(self, x):
        MSE, sigma_rho = self.km.predict_variances_all_levels(x)

        sigma_delta = np.zeros((self.n_lvls,))
        sigma_rho = np.array(sigma_rho)
        theta_vol_lvl = np.ones((self.n_lvls,))
        flags = self.n_lvls * [False]
        for lvl in self.levels:
            if lvl is None:
                lvl = self.n_lvls - 1

            theta_vol_lvl[lvl] = 1.0
            if lvl == 0:
                sigma_delta[lvl] = MSE[0, 0]
                flags[lvl], val = ME(
                    lvl, sigma_delta, sigma_rho, theta_vol_lvl, self.costs
                )
            else:
                sigma_delta[lvl] = MSE[0, lvl] - (MSE[0, lvl - 1]) * sigma_rho[lvl - 1]
                flags[lvl], val = ME(
                    lvl, sigma_delta, sigma_rho, theta_vol_lvl, self.costs, last_val=val
                )
            if not flags[lvl]:
                break

        return flags

    def run(self, budget):
        self.current_cost = 0
        n_iter = 0
        epsilon = 1
        doe_init_size_HF = len(self.doe_y[None])
        doe_init_size_LF = len(self.doe_y[0])
        init_cost = len(sm.training_points[0][0][1]) / self.costs[-1] + len(
            sm.training_points[None][0][1]
        )
        while self.current_cost < budget and epsilon >= self.eps:
            n_iter = n_iter + 1
            # optimization of the EI
            candidat = []
            value = []
            X0 = np.random.rand(self.multi_start, self.dim)

            for i in range(len(self.bounds)):
                X0[:, i] = (
                    X0[:, i] * (-self.bounds[i, 0] + self.bounds[i, 1])
                    + self.bounds[i, 0]
                )
            # Multi start
            for x in X0:
                new_point = sp.optimize.fmin_slsqp(
                    self.compute_EI, np.atleast_2d(x), bounds=self.bounds, iprint=0
                )
                candidat.append(new_point)
                value.append(self.compute_EI(new_point))
            value = np.array(value)

            ind_min = value.argmin()
            x_n = candidat[ind_min].reshape((1, self.dim))
            # Evaluation of the true function(s)
            levels_to_be_added = self.add_level(x_n)

            for lvl in self.levels:
                ll = lvl if lvl is not None else -1
                if levels_to_be_added[ll]:  ## level infill criterion
                    y_n = self.functions[lvl](x_n)
                    y_n = np.atleast_2d(y_n)
                    # updating the kriging meta-model
                    self.doe_x[lvl] = np.insert(self.doe_x[lvl], 0, x_n, axis=0)
                    self.doe_y[lvl] = np.insert(self.doe_y[lvl], 0, y_n, axis=0)
                    self.km.set_training_values(
                        self.doe_x[lvl], self.doe_y[lvl], name=lvl
                    )
            # retraining the model
            self.km.train()

            # computing cost increment
            self.current_cost = self.current_cost + self.cost_increment(
                levels_to_be_added
            )

            # saving data for visualization and postprocesing
            self.cost_hist.append(self.current_cost)
            self.gain.append(self.y0_best - np.min(self.doe_y[None]))
            epsilon = np.abs(np.min(self.doe_y[None]) - self.sol)
            print("######################################")
            print("iteration n=", n_iter)
            print(
                "Number of Hi Fi calls during optimization= ",
                len(self.doe_y[None]) - doe_init_size_HF,
            )
            print(
                "Number of Low Fi calls during optimization= ",
                len(self.doe_y[0]) - doe_init_size_LF,
            )
            print("max EI found at x=", x_n)
            print(
                "Current best value=",
                np.min(self.doe_y[None]),
                " distance to reference solution: ",
                epsilon,
            )
            print("value of the EI =", value.min())
            print(
                "Enrichement current spent budget: ",
                self.current_cost,
                " Total cost including DOE: ",
                self.current_cost + init_cost,
            )
            # add total budget + dif 1D/1D

        Y_min = np.min(self.doe_y[None])
        return Y_min, self.km, self.doe_x, self.doe_y

# %% [markdown]
# Let's apply it to the 2 analytical functions (LF and HF).

# %%
import numpy as np
import matplotlib.pyplot as plt
from smt.applications import MFK

from smt.applications.mfk import NestedLHS

dim = 1
n = 3  # number of high fidelity points (number of low fi is twice)
nlevel = 2
ub0 = 1.0
lb0 = 0.0

xlimits = np.array([[lb0, ub0]])

costs = np.array([1, 100])  # low and high-fidelity costs
# initial_cost = np.sum(np.array(n)*costs)

# np.random.seed(1)
# To create the nested DOE
xdoes = NestedLHS(nlevel=nlevel, xlimits=xlimits)
Xc, Xe = xdoes(n)


yc = LF_function(Xc)
ye = HF_function(Xe)

# time.sleep(5)

sm = MFK(theta0=Xt_e.shape[1] * [1.0], print_global=False)
sm.set_training_values(Xc, yc, name=0)
sm.set_training_values(Xe, ye)
sm.train()

bounds = np.array([[lb0, ub0]])
algo_MFEGO = MFEGO([LF_function, HF_function], sm, bounds, costs=costs, sol=sol_1D)
# Running the EGO algorithm for n_iter
budget = 10
Y_min, sm, doe_x, doe_y = algo_MFEGO.run(budget)

target_level = algo_MFEGO.levels[-1]
# Out:
# ######################################
# iteration n= 1
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  1
# max EI found at x= [[0.75844938]]
# Current best value= -0.6241051730237849  distance to reference solution:  5.396634881786798
# value of the EI = -4.18255780787871
# Enrichement current spent budget:  0.01  Total cost including DOE:  3.07
# ######################################
# iteration n= 2
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  2
# max EI found at x= [[0.75256445]]
# Current best value= -0.6241051730237849  distance to reference solution:  5.396634881786798
# value of the EI = -5.413573132870121
# Enrichement current spent budget:  0.02  Total cost including DOE:  3.08
# ######################################
# iteration n= 3
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  3
# max EI found at x= [[0.75729857]]
# Current best value= -6.020738730352914  distance to reference solution:  1.3244576688720144e-06
# value of the EI = -5.396538172236551
# Enrichement current spent budget:  1.03  Total cost including DOE:  4.09

# %%
print(" MFEGO results: ")
print("Total number of Hi Fi computations (including DOE): ", len(doe_y[None]))
print("Total number of Low Fi computations (including DOE): ", len(doe_y[0]))
# Out:
#  MFEGO results:
# Total number of Hi Fi computations (including DOE):  4
# Total number of Low Fi computations (including DOE):  9

# %% [markdown]
# ## 3- Optimization - 2D

# %% [markdown]
# We are now going to study the convergence of the MFEGO algorithm in a multimodal function, the Branin function. The parameter $A_{corr}$ allows to modify the correlation between the function of HF and the function of LF, $$A_{corr} \in [0, 1]$$
#
# The function of Branin, as well as its low fidelity version, are  both defined as follows
# \begin{align}
#     y_{HF3Opt} & = \left(x_2 - \dfrac{5.1}{4\pi^2}x_1^2 + \dfrac{5}{\pi}x_1 - 6\right)^2 + 10 \left(1 - \dfrac{1}{8\pi}\right)\cos(x_1) + 10\\
#     y_{HF1Opt} & = y_{HF} + 5x_1 \\
#     y_{LF} & = y_{HF3Opt} - (0.5A_{corr}^2 + A_{corr} + 0.2)\left(x_2 - \dfrac{5.1}{4\pi^2}x_1^2 + \dfrac{5}{\pi}x_1 - 6 \right)^2,
#   \qquad  x_1 \in [−5, 10]  \mbox{ and }  x_2 \in [0, 15]
# \end{align}
#
# where $y_{HF3Opt}$ represents the original function with 3 global optimal points, and $y_{HF1Opt}$ represents a variation of the function that presents 2 local optimal points and only 1 global.
#
# The same function of Branin LF as the one presented in the following article has been used
#
# >*A radial basis function-based multi-fidelity surrogate model: exploring correlation between high-fidelity and low-fidelity models.* Structural and Multidisciplinary Optimization. 01/04/2019. Xueguan Song, Liye Lv, Wei Sun, Jie Zhang. https://doi.org/10.1007/s00158-019-02248-0

# %% [markdown]
# ### 3.1 EGO in a 2D function with 3 local minima - Branin function

# %%
def Branin_HF(point):
    # Expensive Branin function
    res = (
        (
            point[:, 1]
            - (5.1 / (4 * np.pi**2)) * point[:, 0] ** 2
            + (5 / np.pi) * point[:, 0]
            - 6
        )
        ** 2
        + 10 * (1 - (1 / 8 / np.pi)) * np.cos(point[:, 0])
        + 10
        + 5 * point[:, 0]
    )
    return res


def Branin_LF(point):
    global A_corr
    # Cheap Branin function
    res = (
        Branin_HF(point)
        - (0.5 * A_corr**2 + A_corr + 0.2)
        * (
            point[:, 1]
            - 5.1 / 4 / np.pi**2 * point[:, 0] ** 2
            + 5 / np.pi * point[:, 0]
            - 6
        )
        ** 2
    )
    return res

# %%
from matplotlib import cm

A_corr = -1
num = 100
x = np.linspace(-5.0, 10.0, num)
y = np.linspace(0.0, 15.0, num)
xv, yv = np.meshgrid(x, y)

x_test = np.array([np.ravel(xv), np.ravel(yv)]).T
z_HF = np.zeros([num * num, 1])
z_HF = Branin_HF(x_test)

fig1 = plt.figure()
axSurrogate1 = fig1.add_subplot(111)
axSurrogate1.set_title("HF function")
surf1 = axSurrogate1.contour(
    xv, yv, z_HF.reshape((num, num)), 300, cmap=cm.PiYG, antialiased=True, alpha=0.6
)
fig1.colorbar(surf1)
fig1.show()
#
num = 100
x = np.linspace(-5.0, 10.0, num)
y = np.linspace(0.0, 15.0, num)
xv, yv = np.meshgrid(x, y)

x_test = np.array([np.ravel(xv), np.ravel(yv)]).T
z_LF = np.zeros([num * num, 1])
z_LF = Branin_LF(x_test)
fig2 = plt.figure()
axSurrogate2 = fig2.add_subplot(111)
axSurrogate2.set_title("LF function")
surf2 = axSurrogate2.contour(
    xv, yv, z_LF.reshape((num, num)), 300, cmap=cm.PiYG, antialiased=True, alpha=0.6
)
fig2.colorbar(surf2)
fig2.show()

# %% [markdown]
# We need to have the reference for optimum. `SLSQP` from scipy is used to get a reference solution.

# %%
x0_Branin = x0_Branin = [-3.5, 14]  # np.atleast_2d([-3.5, 14])

Bound_Branin = ((-5, 10), (0, 15))
res = minimize(
    lambda x: float(Branin_HF(np.atleast_2d(x))),
    x0_Branin,
    method="SLSQP",
    bounds=Bound_Branin,
)
#
print(
    "A local optimal point with initial conditions "
    + str(x0_Branin)
    + " is found in "
    + str(res.x)
    + " with the value "
    + str(res.fun)
)
print("A SLSQP algorithm from scipy has been used.")
sol_Branin = res.fun
# Out:
# A local optimal point with initial conditions [-3.5, 14] is found in [-3.68930439 13.63004733] with the value -16.644021569225643
# A SLSQP algorithm from scipy has been used.

# %% [markdown]
# Using EGO class

# %%
dim = 2
n = 5  # number of doe points
nlevel = 2
ub0 = 10.0
ub1 = 15.0
lb0 = -5.0
lb1 = 0.0
xlimits = np.array([[lb0, ub0], [lb1, ub1]])

# To create the nested DOE
xdoes = LHS(xlimits=xlimits)
Xe = xdoes(n)
ye = Branin_HF(Xe)

sm = KRG(print_global=False)
sm.set_training_values(Xe, ye)
sm.train()

bounds = np.array([[lb0, ub0], [lb1, ub1]])
algo_EGO = EGO(Branin_HF, sm, bounds, sol=sol_Branin)
# Running the EGO algorithm for n_iter=budget
budget = 30
Y_min, sm, doe_x, doe_y = algo_EGO.run(budget)
# Out:
# ######################################
# Iteration n= 1
# Number of Hi Fi calls during optimization=  1
# max EI found at x= [[-5.          8.02574663]]
# Current best value= -9.453907792326383  distance to reference solution:  7.19011377689926
# Value of the EI = -10.776118259499947
# ######################################
# Iteration n= 2
# Number of Hi Fi calls during optimization=  2
# max EI found at x= [[ 9.70396581 11.10224263]]
# Current best value= -9.453907792326383  distance to reference solution:  7.19011377689926
# Value of the EI = -8.769782734363975
# ######################################
# Iteration n= 3
# Number of Hi Fi calls during optimization=  3
# max EI found at x= [[-2.77033145 12.80288103]]
# Current best value= -10.83312503851117  distance to reference solution:  5.810896530714473
# Value of the EI = -9.123472698790962
# ######################################
# Iteration n= 4
# Number of Hi Fi calls during optimization=  4
# max EI found at x= [[-3.1171996   9.39849074]]
# Current best value= -10.83312503851117  distance to reference solution:  5.810896530714473
# Value of the EI = -3.568752437945109
# ######################################
# Iteration n= 5
# Number of Hi Fi calls during optimization=  5
# max EI found at x= [[ 0.90765466 15.        ]]
# Current best value= -10.83312503851117  distance to reference solution:  5.810896530714473
# Value of the EI = -2.1225425130129913
# ######################################
# Iteration n= 6
# Number of Hi Fi calls during optimization=  6
# max EI found at x= [[3.6514173 0.       ]]
# Current best value= -10.83312503851117  distance to reference solution:  5.810896530714473
# Value of the EI = -3.389058265972544
# ######################################
# Iteration n= 7
# Number of Hi Fi calls during optimization=  7
# max EI found at x= [[-3.27518582 15.        ]]
# Current best value= -10.83312503851117  distance to reference solution:  5.810896530714473
# Value of the EI = -10.00232480744335
# ######################################
# Iteration n= 8
# Number of Hi Fi calls during optimization=  8
# max EI found at x= [[-1.78535089 15.        ]]
# Current best value= -10.83312503851117  distance to reference solution:  5.810896530714473
# Value of the EI = -17.638058321617486
# ######################################
# Iteration n= 9
# Number of Hi Fi calls during optimization=  9
# max EI found at x= [[-3.22488328 12.49706073]]
# Current best value= -15.692800917091494  distance to reference solution:  0.9512206521341486
# Value of the EI = -5.0632518830444955
# ######################################
# Iteration n= 10
# Number of Hi Fi calls during optimization=  10
# max EI found at x= [[10.  0.]]
# Current best value= -15.692800917091494  distance to reference solution:  0.9512206521341486
# Value of the EI = -2.146614096364379
# ######################################
# Iteration n= 11
# Number of Hi Fi calls during optimization=  11
# max EI found at x= [[1.73766499 0.        ]]
# Current best value= -15.692800917091494  distance to reference solution:  0.9512206521341486
# Value of the EI = -0.31558799330651777
# ######################################
# Iteration n= 12
# Number of Hi Fi calls during optimization=  12
# max EI found at x= [[-0.24134862  5.42638269]]
# Current best value= -15.692800917091494  distance to reference solution:  0.9512206521341486
# Value of the EI = -5.563236825648001e-06
# ######################################
# Iteration n= 13
# Number of Hi Fi calls during optimization=  13
# max EI found at x= [[-3.42973817 12.91055064]]
# Current best value= -16.35035499132687  distance to reference solution:  0.2936665778987724
# Value of the EI = -0.3526382285239114
# ######################################
# Iteration n= 14
# Number of Hi Fi calls during optimization=  14
# max EI found at x= [[-3.71440384 13.78637481]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -0.33080702427336006
# ######################################
# Iteration n= 15
# Number of Hi Fi calls during optimization=  15
# max EI found at x= [[8.31784529 6.75281237]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -2.6926548798135616e-49
# ######################################
# Iteration n= 16
# Number of Hi Fi calls during optimization=  16
# max EI found at x= [[ 4.97090669 12.27685602]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -1.6913459123069383e-34
# ######################################
# Iteration n= 17
# Number of Hi Fi calls during optimization=  17
# max EI found at x= [[-4.27484477  0.6502081 ]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -2.985031589868773e-34
# ######################################
# Iteration n= 18
# Number of Hi Fi calls during optimization=  18
# max EI found at x= [[7.23839296 2.34625458]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -3.660430149117564e-11
# ######################################
# Iteration n= 19
# Number of Hi Fi calls during optimization=  19
# max EI found at x= [[1.79224533 2.62247339]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -6.4594086987090224e-52
# ######################################
# Iteration n= 20
# Number of Hi Fi calls during optimization=  20
# max EI found at x= [[9.61410562 2.26686254]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -8.272717990482154e-100
# ######################################
# Iteration n= 21
# Number of Hi Fi calls during optimization=  21
# max EI found at x= [[-4.4179206   4.66999317]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -0.0
# ######################################
# Iteration n= 22
# Number of Hi Fi calls during optimization=  22
# max EI found at x= [[-4.64679703 14.43566801]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -2.053525347905298e-70
# ######################################
# Iteration n= 23
# Number of Hi Fi calls during optimization=  23
# max EI found at x= [[-3.70615893 14.05916583]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -3.7124698083031925e-128
# ######################################
# Iteration n= 24
# Number of Hi Fi calls during optimization=  24
# max EI found at x= [[-3.42912714  1.6067966 ]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -0.0
# ######################################
# Iteration n= 25
# Number of Hi Fi calls during optimization=  25
# max EI found at x= [[8.53943381 1.80071201]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -7.415892539196936e-227
# ######################################
# Iteration n= 26
# Number of Hi Fi calls during optimization=  26
# max EI found at x= [[ 4.22500919 11.25327965]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -0.0
# ######################################
# Iteration n= 27
# Number of Hi Fi calls during optimization=  27
# max EI found at x= [[-1.66597785  9.38462481]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -0.0
# ######################################
# Iteration n= 28
# Number of Hi Fi calls during optimization=  28
# max EI found at x= [[-1.47586521  5.11904696]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -0.0
# ######################################
# Iteration n= 29
# Number of Hi Fi calls during optimization=  29
# max EI found at x= [[7.71569904 2.77872637]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -0.0
# ######################################
# Iteration n= 30
# Number of Hi Fi calls during optimization=  30
# max EI found at x= [[2.4204514  6.30752562]]
# Current best value= -16.63291378466822  distance to reference solution:  0.011107784557424338
# Value of the EI = -0.0

# %%
print("Branin - EGO results: ")
print("Total number of Hi Fi computations (including DOE): ", len(doe_y))
# Out:
# Branin - EGO results:
# Total number of Hi Fi computations (including DOE):  35

# %% [markdown]
# Let's visualize the enrichment process.

# %%
doe_size = n
doe = doe_x
response = doe_y

doe_LF = []
response_HF = []

doe_HF = doe
response_HF = response

num = 100
x = np.linspace(-5.0, 10.0, num)
y = np.linspace(0.0, 15.0, num)
xv, yv = np.meshgrid(x, y)

x_test = np.array([np.ravel(xv), np.ravel(yv)]).T
z_HF = np.zeros([num * num, 1])

z_HF = Branin_HF(x_test)
fig1 = plt.figure(figsize=(8, 6))
axSurrogate1 = fig1.add_subplot(111)
surf1 = axSurrogate1.contour(
    xv, yv, z_HF.reshape((num, num)), 150, cmap=cm.PiYG, antialiased=True, alpha=0.6
)

scatter2 = axSurrogate1.scatter(
    doe_HF.T[0][0:doe_size], doe_HF.T[1][0:doe_size], s=20.0, c="b", label="Initial DOE"
)
scatter2 = axSurrogate1.scatter(
    doe_HF.T[0][doe_size:],
    doe_HF.T[1][doe_size:],
    s=20.0,
    c="r",
    label="Enrich HF points",
)
scatter3 = axSurrogate1.scatter(
    -3.68930439, 13.63004733, s=30.0, marker="x", c="C2", label="True Optimum"
)
axSurrogate1.set_xlim([-5, 10])
axSurrogate1.set_ylim([0, 15])
axSurrogate1.set_title(r"2D Branin Function", fontsize=12)
axSurrogate1.legend()
plt.show()

# %% [markdown]
# ### 3.2 MFEGO applied to Branin 2D

# %% [markdown]
# ### <font color='blue'> Exercice:  Create and run the MFEGO problem for Branin 2D </font>

# %%
dim = 2
n = 5  # number of high fidelity points (number of low fi is twice)
nlevel = 2
ub0 = 10.0
ub1 = 15.0
lb0 = -5.0
lb1 = 0.0
xlimits = np.array([[lb0, ub0], [lb1, ub1]])
costs = np.array([1, 10])  # low and high-fidelity costs
initial_cost = np.sum(np.array(n) * costs)

# To create the nested DOE
xdoes = NestedLHS(nlevel=nlevel, xlimits=xlimits)
Xc, Xe = xdoes(n)

yc = Branin_LF(Xc)
ye = Branin_HF(Xe)

sm = MFK(print_global=False)
sm.set_training_values(Xc, yc, name=0)
sm.set_training_values(Xe, ye)
sm.train()

algo_MFEGO = MFEGO(
    [Branin_LF, Branin_HF], sm, bounds=xlimits, costs=costs, sol=sol_Branin
)

# Running the EGO algorithm for a fixed budget
budget = 10
Y_min, sm, doe_x, doe_y = algo_MFEGO.run(budget)
# Out:
# ######################################
# iteration n= 1
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  1
# max EI found at x= [[-5.         12.60979046]]
# Current best value= -3.7530681941126627  distance to reference solution:  12.89095337511298
# value of the EI = -9.562253237598547
# Enrichement current spent budget:  0.1  Total cost including DOE:  6.1
# ######################################
# iteration n= 2
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  2
# max EI found at x= [[-3.08049226 10.83983791]]
# Current best value= -3.7530681941126627  distance to reference solution:  12.89095337511298
# value of the EI = -3.3312363151457243
# Enrichement current spent budget:  0.2  Total cost including DOE:  6.2
# ######################################
# iteration n= 3
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  3
# max EI found at x= [[-3.25906842 10.83130129]]
# Current best value= -3.7530681941126627  distance to reference solution:  12.89095337511298
# value of the EI = -8.033488354522513
# Enrichement current spent budget:  0.30000000000000004  Total cost including DOE:  6.3
# ######################################
# iteration n= 4
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  4
# max EI found at x= [[-3.01282725 11.11061141]]
# Current best value= -3.7530681941126627  distance to reference solution:  12.89095337511298
# value of the EI = -8.320857083121135
# Enrichement current spent budget:  0.4  Total cost including DOE:  6.4
# ######################################
# iteration n= 5
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  5
# max EI found at x= [[-3.05109976 11.18073226]]
# Current best value= -3.7530681941126627  distance to reference solution:  12.89095337511298
# value of the EI = -8.423663016048389
# Enrichement current spent budget:  0.5  Total cost including DOE:  6.5
# ######################################
# iteration n= 6
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  6
# max EI found at x= [[1.38404216 0.        ]]
# Current best value= -3.7530681941126627  distance to reference solution:  12.89095337511298
# value of the EI = -0.580737021618444
# Enrichement current spent budget:  0.6  Total cost including DOE:  6.6
# ######################################
# iteration n= 7
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  7
# max EI found at x= [[-3.52821887 12.73272784]]
# Current best value= -3.7530681941126627  distance to reference solution:  12.89095337511298
# value of the EI = -10.094500748767894
# Enrichement current spent budget:  0.7  Total cost including DOE:  6.7
# ######################################
# iteration n= 8
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  8
# max EI found at x= [[10.  0.]]
# Current best value= -3.7530681941126627  distance to reference solution:  12.89095337511298
# value of the EI = -2.8852422827350974
# Enrichement current spent budget:  0.7999999999999999  Total cost including DOE:  6.8
# ######################################
# iteration n= 9
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  9
# max EI found at x= [[-3.84212648 14.0093189 ]]
# Current best value= -3.7530681941126627  distance to reference solution:  12.89095337511298
# value of the EI = -11.074922789371557
# Enrichement current spent budget:  0.8999999999999999  Total cost including DOE:  6.9
# ######################################
# iteration n= 10
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  10
# max EI found at x= [[3.54149458 2.47986275]]
# Current best value= -3.7530681941126627  distance to reference solution:  12.89095337511298
# value of the EI = -2.196142473549532e-14
# Enrichement current spent budget:  0.9999999999999999  Total cost including DOE:  7.0
# ######################################
# iteration n= 11
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  11
# max EI found at x= [[-3.78924921 13.83578453]]
# Current best value= -3.7530681941126627  distance to reference solution:  12.89095337511298
# value of the EI = -10.999094900858248
# Enrichement current spent budget:  1.0999999999999999  Total cost including DOE:  7.1
# ######################################
# iteration n= 12
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  12
# max EI found at x= [[-2.69740016  8.45642963]]
# Current best value= -3.7530681941126627  distance to reference solution:  12.89095337511298
# value of the EI = -3.201899637988495e-07
# Enrichement current spent budget:  1.2  Total cost including DOE:  7.2
# ######################################
# iteration n= 13
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  13
# max EI found at x= [[-3.77744055 13.77300694]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -10.998232042991846
# Enrichement current spent budget:  2.3  Total cost including DOE:  8.3
# ######################################
# iteration n= 14
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  14
# max EI found at x= [[7.83320434 0.90828623]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -8.89085990446181e-69
# Enrichement current spent budget:  2.4  Total cost including DOE:  8.4
# ######################################
# iteration n= 15
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  15
# max EI found at x= [[ 8.40644936 10.97979264]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -1.1755736875226962e-55
# Enrichement current spent budget:  2.5  Total cost including DOE:  8.5
# ######################################
# iteration n= 16
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  16
# max EI found at x= [[-1.68397763 13.81718522]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  2.6  Total cost including DOE:  8.6
# ######################################
# iteration n= 17
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  17
# max EI found at x= [[-3.16858665  8.66981636]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  2.7  Total cost including DOE:  8.7
# ######################################
# iteration n= 18
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  18
# max EI found at x= [[-4.26352961  5.98239398]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  2.8000000000000003  Total cost including DOE:  8.8
# ######################################
# iteration n= 19
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  19
# max EI found at x= [[9.0018175  3.22741778]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -1.5126409186065693e-303
# Enrichement current spent budget:  2.9000000000000004  Total cost including DOE:  8.9
# ######################################
# iteration n= 20
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  20
# max EI found at x= [[8.69647097 2.96975784]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  3.0000000000000004  Total cost including DOE:  9.0
# ######################################
# iteration n= 21
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  21
# max EI found at x= [[-1.72251909  9.27571946]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  3.1000000000000005  Total cost including DOE:  9.100000000000001
# ######################################
# iteration n= 22
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  22
# max EI found at x= [[-1.09858887  9.85224926]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  3.2000000000000006  Total cost including DOE:  9.200000000000001
# ######################################
# iteration n= 23
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  23
# max EI found at x= [[-2.51988582  2.48360119]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  3.3000000000000007  Total cost including DOE:  9.3
# ######################################
# iteration n= 24
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  24
# max EI found at x= [[-0.10389597 11.68550901]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  3.400000000000001  Total cost including DOE:  9.4
# ######################################
# iteration n= 25
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  25
# max EI found at x= [[9.42616501 1.43038842]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  3.500000000000001  Total cost including DOE:  9.5
# ######################################
# iteration n= 26
# Number of Hi Fi calls during optimization=  1
# Number of Low Fi calls during optimization=  26
# max EI found at x= [[-3.41140032 14.02947633]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  3.600000000000001  Total cost including DOE:  9.600000000000001
# ######################################
# iteration n= 27
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  27
# max EI found at x= [[-3.99799113 13.40332362]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -1.1671679e-315
# Enrichement current spent budget:  4.700000000000001  Total cost including DOE:  10.700000000000001
# ######################################
# iteration n= 28
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  28
# max EI found at x= [[9.12151117 1.33099033]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  4.800000000000001  Total cost including DOE:  10.8
# ######################################
# iteration n= 29
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  29
# max EI found at x= [[-2.8192224  0.6665162]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  4.9  Total cost including DOE:  10.9
# ######################################
# iteration n= 30
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  30
# max EI found at x= [[0.47191611 1.76030653]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  5.0  Total cost including DOE:  11.0
# ######################################
# iteration n= 31
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  31
# max EI found at x= [[8.49131069 5.96853194]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  5.1  Total cost including DOE:  11.1
# ######################################
# iteration n= 32
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  32
# max EI found at x= [[-0.77194638  3.47041972]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  5.199999999999999  Total cost including DOE:  11.2
# ######################################
# iteration n= 33
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  33
# max EI found at x= [[0.53502272 6.25028188]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  5.299999999999999  Total cost including DOE:  11.299999999999999
# ######################################
# iteration n= 34
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  34
# max EI found at x= [[-3.18737492 13.85325285]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  5.399999999999999  Total cost including DOE:  11.399999999999999
# ######################################
# iteration n= 35
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  35
# max EI found at x= [[-0.00665271  5.64560472]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  5.499999999999998  Total cost including DOE:  11.499999999999998
# ######################################
# iteration n= 36
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  36
# max EI found at x= [[ 2.08304851 10.32497106]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  5.599999999999998  Total cost including DOE:  11.599999999999998
# ######################################
# iteration n= 37
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  37
# max EI found at x= [[-4.24250808 14.63502068]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -2.2111348936766715e-92
# Enrichement current spent budget:  5.6999999999999975  Total cost including DOE:  11.699999999999998
# ######################################
# iteration n= 38
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  38
# max EI found at x= [[7.65292929 3.38275629]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  5.799999999999997  Total cost including DOE:  11.799999999999997
# ######################################
# iteration n= 39
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  39
# max EI found at x= [[2.17000237 9.0675538 ]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  5.899999999999997  Total cost including DOE:  11.899999999999997
# ######################################
# iteration n= 40
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  40
# max EI found at x= [[2.08564427 1.12074752]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  5.9999999999999964  Total cost including DOE:  11.999999999999996
# ######################################
# iteration n= 41
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  41
# max EI found at x= [[ 7.17654329 14.40343345]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  6.099999999999996  Total cost including DOE:  12.099999999999996
# ######################################
# iteration n= 42
# Number of Hi Fi calls during optimization=  2
# Number of Low Fi calls during optimization=  42
# max EI found at x= [[1.67967387 4.89751819]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  6.199999999999996  Total cost including DOE:  12.199999999999996
# ######################################
# iteration n= 43
# Number of Hi Fi calls during optimization=  3
# Number of Low Fi calls during optimization=  43
# max EI found at x= [[-3.2830317  12.42209958]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  7.299999999999995  Total cost including DOE:  13.299999999999995
# ######################################
# iteration n= 44
# Number of Hi Fi calls during optimization=  4
# Number of Low Fi calls during optimization=  44
# max EI found at x= [[2.20464906 2.38361163]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -7.10868142703563e-310
# Enrichement current spent budget:  8.399999999999995  Total cost including DOE:  14.399999999999995
# ######################################
# iteration n= 45
# Number of Hi Fi calls during optimization=  5
# Number of Low Fi calls during optimization=  45
# max EI found at x= [[-1.39599278  3.42368848]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  9.499999999999995  Total cost including DOE:  15.499999999999995
# ######################################
# iteration n= 46
# Number of Hi Fi calls during optimization=  5
# Number of Low Fi calls during optimization=  46
# max EI found at x= [[-3.01733947  2.78259444]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  9.599999999999994  Total cost including DOE:  15.599999999999994
# ######################################
# iteration n= 47
# Number of Hi Fi calls during optimization=  5
# Number of Low Fi calls during optimization=  47
# max EI found at x= [[ 2.78828603 13.64168228]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  9.699999999999994  Total cost including DOE:  15.699999999999994
# ######################################
# iteration n= 48
# Number of Hi Fi calls during optimization=  6
# Number of Low Fi calls during optimization=  48
# max EI found at x= [[8.94960347 5.24614069]]
# Current best value= -16.605983497387875  distance to reference solution:  0.03803807183776797
# value of the EI = -0.0
# Enrichement current spent budget:  10.799999999999994  Total cost including DOE:  16.799999999999994

# %% [markdown]
# ## 3.3  Try with another  2D function: 2D Rosenbrock function

# %% [markdown]
# Rosenbrock Function  in dimension N
#
# $$
# f(\mathbf{x}) = \sum_{i=1}^{N-1} 100 (x_{i+1} - x_i^2 )^2 + (1-x_i)^2 \quad \mbox{where} \quad \mathbf{x} = [x_1, \ldots, x_N] \in \mathbb{R}^N.
# $$
#
# $$x_i \in [-2,2]$$

# %%
def Rosen_HF(point):
    # Expensive Rosen function

    res = (1.0 - point[:, 0]) ** 2 + 100 * (point[:, 1] - point[:, 0] ** 2) ** 2
    return res


def Rosen_LF(point):
    # Expensive Rosen function

    res = (
        (1.0 - point[:, 0]) ** 2
        + 100 * (point[:, 1] - point[:, 0] ** 2) ** 2
        + 0.1 * np.sin(10 * point[:, 0] + 5 * point[:, 1])
    )

    return res

# %%
num = 100
x = np.linspace(-2.0, 2.0, num)
y = np.linspace(-2.0, 2.0, num)
xv, yv = np.meshgrid(x, y)

x_test = np.array([np.ravel(xv), np.ravel(yv)]).T
z_HF = np.zeros([num * num, 1])
z_HF = Rosen_HF(x_test)

fig1 = plt.figure()
axSurrogate1 = fig1.add_subplot(111)
axSurrogate1.set_title("HF function")
surf1 = axSurrogate1.contour(
    xv, yv, z_HF.reshape((num, num)), 300, cmap=cm.PiYG, antialiased=True, alpha=0.6
)
fig1.colorbar(surf1)
fig1.show()
#
num = 100
x = np.linspace(-2.0, 2.0, num)
y = np.linspace(-2.0, 2.0, num)
xv, yv = np.meshgrid(x, y)

x_test = np.array([np.ravel(xv), np.ravel(yv)]).T
z_LF = np.zeros([num * num, 1])
z_LF = Rosen_LF(x_test)

fig2 = plt.figure()
axSurrogate2 = fig2.add_subplot(111)
axSurrogate2.set_title("LF function")
surf2 = axSurrogate2.contour(
    xv, yv, z_LF.reshape((num, num)), 300, cmap=cm.PiYG, antialiased=True, alpha=0.6
)
fig2.colorbar(surf2)
plt.show()

# %% [markdown]
# Finding the optimum.

# %% [markdown]
# ### <font color='blue'>Exercice:  find the optimum for Rosenbrock using the minimize with SLSQP </font>

# %%
x0_Rosen = [-0, 0]

Bound_Rosen = ((-2, 2), (-2, 2))
res = minimize(
    lambda x: float(Rosen_HF(np.atleast_2d(x))),
    x0_Rosen,
    method="SLSQP",
    bounds=Bound_Rosen,
)

print(
    "A local optimal point with initial conditions "
    + str(x0_Rosen)
    + " is found in "
    + str(res.x)
    + " with the value "
    + str(res.fun)
)
print("A SLSQP algorithm from scipy has been used")
sol_Rosen = res.fun
# Out:
# A local optimal point with initial conditions [0, 0] is found in [0.9997756  0.99955541] with the value 5.2084018504060325e-08
# A SLSQP algorithm from scipy has been used

# %% [markdown]
# Using EGO

# %% [markdown]
# ### <font color='blue'>Exercice:  Optimize Rosenbrock with EGO </font>

# %%
dim = 2
n = 5  # number of doe points
nlevel = 2
ub0 = 2.0
ub1 = 2.0
lb0 = -2.0
lb1 = -2.0
xlimits = np.array([[lb0, ub0], [lb1, ub1]])

# To create the nested DOE
xdoes = LHS(xlimits=xlimits)
Xe = xdoes(n)
ye = Rosen_HF(Xe)


sm = KRG(print_global=False)
sm.set_training_values(Xe, ye)
sm.train()

algo_EGO = EGO(Rosen_HF, sm, bounds=xlimits, sol=sol_Rosen)
# Running the EGO algorithm for niter=budget
budget = 40
Y_min, sm, doe_x, doe_y = algo_EGO.run(budget)


doe = doe_x
response = doe_y

n = doe_size
doe_LF = []
response_HF = []
doe_HF = doe
response_HF = response

num = 100
x = np.linspace(-2.0, 2.0, num)
y = np.linspace(-2.0, 2.0, num)
xv, yv = np.meshgrid(x, y)

x_test = np.array([np.ravel(xv), np.ravel(yv)]).T
z_HF = np.zeros([num * num, 1])
z_HF = Rosen_HF(x_test)
fig1 = plt.figure(figsize=(8, 6))
axSurrogate1 = fig1.add_subplot(111)
surf1 = axSurrogate1.contour(
    xv, yv, z_HF.reshape((num, num)), 150, cmap=cm.PiYG, antialiased=True, alpha=0.6
)
scatter2 = axSurrogate1.scatter(
    doe_HF.T[0][0:doe_size], doe_HF.T[1][0:doe_size], s=20.0, c="b", label="Initial DOE"
)
scatter2 = axSurrogate1.scatter(
    doe_HF.T[0][doe_size:],
    doe_HF.T[1][doe_size:],
    s=20.0,
    c="r",
    label="Enrich HF points",
)
scatter3 = axSurrogate1.scatter(1, 1, s=30.0, marker="x", c="C2", label="True Optimum")
axSurrogate1.set_xlim([-2, 2])
axSurrogate1.set_ylim([-2, 2])
axSurrogate1.set_title(r"2D Rosen Function", fontsize=12)
axSurrogate1.legend()
plt.show()
# Out:
# ######################################
# Iteration n= 1
# Number of Hi Fi calls during optimization=  1
# max EI found at x= [[-0.70114461  0.19366449]]
# Current best value= 11.770674289076684  distance to reference solution:  11.770674236992665
# Value of the EI = -75.29784510781968
# ######################################
# Iteration n= 2
# Number of Hi Fi calls during optimization=  2
# max EI found at x= [[ 1.11905971 -0.86808121]]
# Current best value= 11.770674289076684  distance to reference solution:  11.770674236992665
# Value of the EI = -17.46425673079533
# ######################################
# Iteration n= 3
# Number of Hi Fi calls during optimization=  3
# max EI found at x= [[-0.61664624 -2.        ]]
# Current best value= 11.770674289076684  distance to reference solution:  11.770674236992665
# Value of the EI = -60.246222500953074
# ######################################
# Iteration n= 4
# Number of Hi Fi calls during optimization=  4
# max EI found at x= [[-0.88219196  0.85911397]]
# Current best value= 4.196340240586875  distance to reference solution:  4.196340188502856
# Value of the EI = -45.931785573664385
# ######################################
# Iteration n= 5
# Number of Hi Fi calls during optimization=  5
# max EI found at x= [[0.34780193 0.99255031]]
# Current best value= 4.196340240586875  distance to reference solution:  4.196340188502856
# Value of the EI = -43.03437333200287
# ######################################
# Iteration n= 6
# Number of Hi Fi calls during optimization=  6
# max EI found at x= [[-0.72998361  0.94423805]]
# Current best value= 4.196340240586875  distance to reference solution:  4.196340188502856
# Value of the EI = -39.396025316915164
# ######################################
# Iteration n= 7
# Number of Hi Fi calls during optimization=  7
# max EI found at x= [[0.41592263 2.        ]]
# Current best value= 4.196340240586875  distance to reference solution:  4.196340188502856
# Value of the EI = -21.931263959165136
# ######################################
# Iteration n= 8
# Number of Hi Fi calls during optimization=  8
# max EI found at x= [[0.46931512 0.04849271]]
# Current best value= 3.2319123995121113  distance to reference solution:  3.231912347428093
# Value of the EI = -54.66670755880498
# ######################################
# Iteration n= 9
# Number of Hi Fi calls during optimization=  9
# max EI found at x= [[0.66274794 0.57948662]]
# Current best value= 2.080795596149204  distance to reference solution:  2.0807955440651855
# Value of the EI = -13.071833225514911
# ######################################
# Iteration n= 10
# Number of Hi Fi calls during optimization=  10
# max EI found at x= [[0.49775481 0.28987803]]
# Current best value= 0.4296443421859616  distance to reference solution:  0.4296442901019431
# Value of the EI = -3.4211935192795906
# ######################################
# Iteration n= 11
# Number of Hi Fi calls during optimization=  11
# max EI found at x= [[1.07152416 1.3102951 ]]
# Current best value= 0.4296443421859616  distance to reference solution:  0.4296442901019431
# Value of the EI = -1.6927433122627345e-30
# ######################################
# Iteration n= 12
# Number of Hi Fi calls during optimization=  12
# max EI found at x= [[-1.40230544  2.        ]]
# Current best value= 0.4296443421859616  distance to reference solution:  0.4296442901019431
# Value of the EI = -9.245401096445896
# ######################################
# Iteration n= 13
# Number of Hi Fi calls during optimization=  13
# max EI found at x= [[ 0.11289951 -0.00651673]]
# Current best value= 0.4296443421859616  distance to reference solution:  0.4296442901019431
# Value of the EI = -0.08277306954721385
# ######################################
# Iteration n= 14
# Number of Hi Fi calls during optimization=  14
# max EI found at x= [[1.31017069 1.67085122]]
# Current best value= 0.3050183618395485  distance to reference solution:  0.30501830975553
# Value of the EI = -0.18761543132618502
# ######################################
# Iteration n= 15
# Number of Hi Fi calls during optimization=  15
# max EI found at x= [[1.11683546 1.18474275]]
# Current best value= 0.3050183618395485  distance to reference solution:  0.30501830975553
# Value of the EI = -7.865188030275152e-08
# ######################################
# Iteration n= 16
# Number of Hi Fi calls during optimization=  16
# max EI found at x= [[ 0.64469773 -0.08342603]]
# Current best value= 0.3050183618395485  distance to reference solution:  0.30501830975553
# Value of the EI = -0.0
# ######################################
# Iteration n= 17
# Number of Hi Fi calls during optimization=  17
# max EI found at x= [[0.92360648 0.74784337]]
# Current best value= 0.3050183618395485  distance to reference solution:  0.30501830975553
# Value of the EI = -3.713953417721129e-214
# ######################################
# Iteration n= 18
# Number of Hi Fi calls during optimization=  18
# max EI found at x= [[ 0.6414936  -0.80793653]]
# Current best value= 0.3050183618395485  distance to reference solution:  0.30501830975553
# Value of the EI = -0.0
# ######################################
# Iteration n= 19
# Number of Hi Fi calls during optimization=  19
# max EI found at x= [[0.77002011 0.67921433]]
# Current best value= 0.3050183618395485  distance to reference solution:  0.30501830975553
# Value of the EI = -1.4951805630573102e-236
# ######################################
# Iteration n= 20
# Number of Hi Fi calls during optimization=  20
# max EI found at x= [[-0.41809104 -1.48119044]]
# Current best value= 0.3050183618395485  distance to reference solution:  0.30501830975553
# Value of the EI = -0.0
# ######################################
# Iteration n= 21
# Number of Hi Fi calls during optimization=  21
# max EI found at x= [[-0.35377415  0.03411344]]
# Current best value= 0.3050183618395485  distance to reference solution:  0.30501830975553
# Value of the EI = -0.0
# ######################################
# Iteration n= 22
# Number of Hi Fi calls during optimization=  22
# max EI found at x= [[1.04685816 1.10703866]]
# Current best value= 0.014575957386511055  distance to reference solution:  0.01457590530249255
# Value of the EI = -0.2908415890136857
# ######################################
# Iteration n= 23
# Number of Hi Fi calls during optimization=  23
# max EI found at x= [[1.11202293 1.81386525]]
# Current best value= 0.014575957386511055  distance to reference solution:  0.01457590530249255
# Value of the EI = -0.0
# ######################################
# Iteration n= 24
# Number of Hi Fi calls during optimization=  24
# max EI found at x= [[1.01521941 1.0233014 ]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -0.008624566642432597
# ######################################
# Iteration n= 25
# Number of Hi Fi calls during optimization=  25
# max EI found at x= [[1.39847988 1.92613066]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -4.40087150382095e-09
# ######################################
# Iteration n= 26
# Number of Hi Fi calls during optimization=  26
# max EI found at x= [[-0.26278078  1.42762767]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -0.0
# ######################################
# Iteration n= 27
# Number of Hi Fi calls during optimization=  27
# max EI found at x= [[0.59160441 0.34002758]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -5.293329569761321e-109
# ######################################
# Iteration n= 28
# Number of Hi Fi calls during optimization=  28
# max EI found at x= [[-1.26427739 -0.77163562]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -0.0
# ######################################
# Iteration n= 29
# Number of Hi Fi calls during optimization=  29
# max EI found at x= [[1.06336731 1.16423401]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -1.8728959365495834e-66
# ######################################
# Iteration n= 30
# Number of Hi Fi calls during optimization=  30
# max EI found at x= [[-1.14750819 -0.57174105]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -0.0
# ######################################
# Iteration n= 31
# Number of Hi Fi calls during optimization=  31
# max EI found at x= [[-0.32051526 -0.91560448]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -0.0
# ######################################
# Iteration n= 32
# Number of Hi Fi calls during optimization=  32
# max EI found at x= [[-1.34724869 -0.54307873]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -0.0
# ######################################
# Iteration n= 33
# Number of Hi Fi calls during optimization=  33
# max EI found at x= [[-1.27568325  1.34799013]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -0.0
# ######################################
# Iteration n= 34
# Number of Hi Fi calls during optimization=  34
# max EI found at x= [[1.51042302 0.7408484 ]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -0.0
# ######################################
# Iteration n= 35
# Number of Hi Fi calls during optimization=  35
# max EI found at x= [[ 1.41574418 -0.6153872 ]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -0.0
# ######################################
# Iteration n= 36
# Number of Hi Fi calls during optimization=  36
# max EI found at x= [[-0.12734118 -0.91491214]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -0.0
# ######################################
# Iteration n= 37
# Number of Hi Fi calls during optimization=  37
# max EI found at x= [[-0.88722682 -1.4677861 ]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -0.0
# ######################################
# Iteration n= 38
# Number of Hi Fi calls during optimization=  38
# max EI found at x= [[-1.51124883  0.43542318]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -0.0
# ######################################
# Iteration n= 39
# Number of Hi Fi calls during optimization=  39
# max EI found at x= [[ 0.33087391 -0.03267802]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -0.0
# ######################################
# Iteration n= 40
# Number of Hi Fi calls during optimization=  40
# max EI found at x= [[0.58061495 0.77844128]]
# Current best value= 0.005661926223379094  distance to reference solution:  0.00566187413936059
# Value of the EI = -0.0

# %% [markdown]
# Using MFEGO

# %% [markdown]
# ### <font color='blue'>Exercice:  Optimize Rosenbrock with MFEGO </font>

# %%
dim = 2
n = 5  # number of high fidelity points (number of low fi is twice)
nlevel = 2
ub0 = 2.0
ub1 = 2.0
lb0 = -2.0
lb1 = -2.0
xlimits = np.array([[lb0, ub0], [lb1, ub1]])

costs = np.array([1, 2])  # low and high-fidelity costs
initial_cost = np.sum(np.array(n) * costs)
# np.random.seed(1)
# To create the nested DOE
xdoes = NestedLHS(nlevel=nlevel, xlimits=xlimits)
Xc, Xe = xdoes(n)


yc = Rosen_LF(Xc)
ye = Rosen_HF(Xe)


sm = MFK(print_global=False)
sm.set_training_values(Xc, yc, name=0)
sm.set_training_values(Xe, ye)
sm.train()

bounds = np.array([[lb0, ub0], [lb1, ub1]])
algo_EGO = MFEGO([Rosen_LF, Rosen_HF], sm, bounds, costs=costs, sol=sol_Rosen)
# Running the MFEGO algorithm for a fixed budget
budget = 40
Y_min, sm, doe_x, doe_y = algo_EGO.run(budget)
# Out:
# ######################################
# iteration n= 1
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  1
# max EI found at x= [[1.23841912 0.09134897]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -128.4630264498931
# Enrichement current spent budget:  0.5  Total cost including DOE:  10.5
# ######################################
# iteration n= 2
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  2
# max EI found at x= [[-1.10741109 -0.01581253]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -193.2735493490914
# Enrichement current spent budget:  1.0  Total cost including DOE:  11.0
# ######################################
# iteration n= 3
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  3
# max EI found at x= [[0.92387683 0.82276967]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -85.92153446847831
# Enrichement current spent budget:  1.5  Total cost including DOE:  11.5
# ######################################
# iteration n= 4
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  4
# max EI found at x= [[1.30617288 2.        ]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -32.350784365808444
# Enrichement current spent budget:  2.0  Total cost including DOE:  12.0
# ######################################
# iteration n= 5
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  5
# max EI found at x= [[-0.98163283  1.06264375]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -14.484540826516906
# Enrichement current spent budget:  2.5  Total cost including DOE:  12.5
# ######################################
# iteration n= 6
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  6
# max EI found at x= [[0.49349829 0.18765842]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.050431712134481
# Enrichement current spent budget:  3.0  Total cost including DOE:  13.0
# ######################################
# iteration n= 7
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  7
# max EI found at x= [[ 0.2524753  -0.01081876]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -5.365498365582324
# Enrichement current spent budget:  3.5  Total cost including DOE:  13.5
# ######################################
# iteration n= 8
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  8
# max EI found at x= [[0.96400347 0.99187386]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.866369191611183
# Enrichement current spent budget:  4.0  Total cost including DOE:  14.0
# ######################################
# iteration n= 9
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  9
# max EI found at x= [[-0.5098362   0.23791719]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -4.194960859050083
# Enrichement current spent budget:  4.5  Total cost including DOE:  14.5
# ######################################
# iteration n= 10
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  10
# max EI found at x= [[1.35523954 1.80403315]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.685006172630734
# Enrichement current spent budget:  5.0  Total cost including DOE:  15.0
# ######################################
# iteration n= 11
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  11
# max EI found at x= [[1.0024851  0.79353578]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -2.140551964312989
# Enrichement current spent budget:  5.5  Total cost including DOE:  15.5
# ######################################
# iteration n= 12
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  12
# max EI found at x= [[0.66708815 0.20802551]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.9640801819383125
# Enrichement current spent budget:  6.0  Total cost including DOE:  16.0
# ######################################
# iteration n= 13
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  13
# max EI found at x= [[1.16852656 1.38412044]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.609287185227528
# Enrichement current spent budget:  6.5  Total cost including DOE:  16.5
# ######################################
# iteration n= 14
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  14
# max EI found at x= [[0.63791482 0.39887934]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.450693795022358
# Enrichement current spent budget:  7.0  Total cost including DOE:  17.0
# ######################################
# iteration n= 15
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  15
# max EI found at x= [[1.94212551 0.76836375]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.0
# Enrichement current spent budget:  7.5  Total cost including DOE:  17.5
# ######################################
# iteration n= 16
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  16
# max EI found at x= [[ 0.63718066 -1.77899235]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.0
# Enrichement current spent budget:  8.0  Total cost including DOE:  18.0
# ######################################
# iteration n= 17
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  17
# max EI found at x= [[-0.24986994  0.07131071]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -5.044452607470147
# Enrichement current spent budget:  8.5  Total cost including DOE:  18.5
# ######################################
# iteration n= 18
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  18
# max EI found at x= [[0.49716681 0.11694742]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -4.663029085999211
# Enrichement current spent budget:  9.0  Total cost including DOE:  19.0
# ######################################
# iteration n= 19
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  19
# max EI found at x= [[-0.26080163  0.14586795]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -4.445653902031564
# Enrichement current spent budget:  9.5  Total cost including DOE:  19.5
# ######################################
# iteration n= 20
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  20
# max EI found at x= [[-0.14541199  0.16055878]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -3.41911615332951
# Enrichement current spent budget:  10.0  Total cost including DOE:  20.0
# ######################################
# iteration n= 21
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  21
# max EI found at x= [[-0.30415949  0.05843516]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -4.846318614194571
# Enrichement current spent budget:  10.5  Total cost including DOE:  20.5
# ######################################
# iteration n= 22
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  22
# max EI found at x= [[1.39678041 1.6607308 ]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -1.0176710276632826e-182
# Enrichement current spent budget:  11.0  Total cost including DOE:  21.0
# ######################################
# iteration n= 23
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  23
# max EI found at x= [[1.01342038 1.02173674]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.5987957922213365
# Enrichement current spent budget:  11.5  Total cost including DOE:  21.5
# ######################################
# iteration n= 24
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  24
# max EI found at x= [[-0.13076428  0.04399269]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -5.337319481092363
# Enrichement current spent budget:  12.0  Total cost including DOE:  22.0
# ######################################
# iteration n= 25
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  25
# max EI found at x= [[0.12962363 0.05891377]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -5.745914063624651
# Enrichement current spent budget:  12.5  Total cost including DOE:  22.5
# ######################################
# iteration n= 26
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  26
# max EI found at x= [[0.75235284 0.65672428]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -5.6900101178847375
# Enrichement current spent budget:  13.0  Total cost including DOE:  23.0
# ######################################
# iteration n= 27
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  27
# max EI found at x= [[0.85702665 0.89770867]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -3.9328286489851063
# Enrichement current spent budget:  13.5  Total cost including DOE:  23.5
# ######################################
# iteration n= 28
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  28
# max EI found at x= [[-0.69139462  0.62006304]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -1.6948952241907147
# Enrichement current spent budget:  14.0  Total cost including DOE:  24.0
# ######################################
# iteration n= 29
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  29
# max EI found at x= [[ 1.9435243  -1.82809707]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.0
# Enrichement current spent budget:  14.5  Total cost including DOE:  24.5
# ######################################
# iteration n= 30
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  30
# max EI found at x= [[-0.05877934  0.08049764]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -4.9698751390794325
# Enrichement current spent budget:  15.0  Total cost including DOE:  25.0
# ######################################
# iteration n= 31
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  31
# max EI found at x= [[-0.94920127  1.01654891]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -1.4310252447583434
# Enrichement current spent budget:  15.5  Total cost including DOE:  25.5
# ######################################
# iteration n= 32
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  32
# max EI found at x= [[-1.45737294  1.81156015]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -8.253975124488618e-45
# Enrichement current spent budget:  16.0  Total cost including DOE:  26.0
# ######################################
# iteration n= 33
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  33
# max EI found at x= [[1.39363516 1.95456045]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.619047821154693
# Enrichement current spent budget:  16.5  Total cost including DOE:  26.5
# ######################################
# iteration n= 34
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  34
# max EI found at x= [[0.59847544 0.35165022]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.45531013949538
# Enrichement current spent budget:  17.0  Total cost including DOE:  27.0
# ######################################
# iteration n= 35
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  35
# max EI found at x= [[-0.09320407 -0.09068553]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -4.523142820799007
# Enrichement current spent budget:  17.5  Total cost including DOE:  27.5
# ######################################
# iteration n= 36
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  36
# max EI found at x= [[-0.55308729 -1.17960634]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.0
# Enrichement current spent budget:  18.0  Total cost including DOE:  28.0
# ######################################
# iteration n= 37
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  37
# max EI found at x= [[1.26434119 1.44398819]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -4.25270450233104
# Enrichement current spent budget:  18.5  Total cost including DOE:  28.5
# ######################################
# iteration n= 38
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  38
# max EI found at x= [[1.34183947 1.63744896]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -3.9476681716796076
# Enrichement current spent budget:  19.0  Total cost including DOE:  29.0
# ######################################
# iteration n= 39
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  39
# max EI found at x= [[-0.44056353 -0.04582323]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -1.4249744183079738e-282
# Enrichement current spent budget:  19.5  Total cost including DOE:  29.5
# ######################################
# iteration n= 40
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  40
# max EI found at x= [[0.35103557 0.0026008 ]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -4.785563170556669
# Enrichement current spent budget:  20.0  Total cost including DOE:  30.0
# ######################################
# iteration n= 41
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  41
# max EI found at x= [[0.51180774 0.31376562]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.137643682411335
# Enrichement current spent budget:  20.5  Total cost including DOE:  30.5
# ######################################
# iteration n= 42
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  42
# max EI found at x= [[-0.14831916 -0.96986987]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.0
# Enrichement current spent budget:  21.0  Total cost including DOE:  31.0
# ######################################
# iteration n= 43
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  43
# max EI found at x= [[-1.36827264 -0.91978201]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.0
# Enrichement current spent budget:  21.5  Total cost including DOE:  31.5
# ######################################
# iteration n= 44
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  44
# max EI found at x= [[ 0.04659939 -0.21225625]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -1.1737396735156391
# Enrichement current spent budget:  22.0  Total cost including DOE:  32.0
# ######################################
# iteration n= 45
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  45
# max EI found at x= [[1.13999472 1.17306756]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -5.004521407668262
# Enrichement current spent budget:  22.5  Total cost including DOE:  32.5
# ######################################
# iteration n= 46
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  46
# max EI found at x= [[-0.91668192  0.98453971]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.8004921523950497
# Enrichement current spent budget:  23.0  Total cost including DOE:  33.0
# ######################################
# iteration n= 47
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  47
# max EI found at x= [[-0.32802769  0.27517866]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -2.101962292788455
# Enrichement current spent budget:  23.5  Total cost including DOE:  33.5
# ######################################
# iteration n= 48
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  48
# max EI found at x= [[-0.55236918  0.21632892]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -3.4268730604332927
# Enrichement current spent budget:  24.0  Total cost including DOE:  34.0
# ######################################
# iteration n= 49
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  49
# max EI found at x= [[0.55604788 0.35964399]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.180446191483936
# Enrichement current spent budget:  24.5  Total cost including DOE:  34.5
# ######################################
# iteration n= 50
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  50
# max EI found at x= [[-0.5230832   0.14704132]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -2.6988581707453374
# Enrichement current spent budget:  25.0  Total cost including DOE:  35.0
# ######################################
# iteration n= 51
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  51
# max EI found at x= [[0.40768404 0.2780595 ]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -5.056622322384824
# Enrichement current spent budget:  25.5  Total cost including DOE:  35.5
# ######################################
# iteration n= 52
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  52
# max EI found at x= [[1.10737744 1.19524512]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.530522587935804
# Enrichement current spent budget:  26.0  Total cost including DOE:  36.0
# ######################################
# iteration n= 53
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  53
# max EI found at x= [[0.95677687 0.84055228]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.055753966485595
# Enrichement current spent budget:  26.5  Total cost including DOE:  36.5
# ######################################
# iteration n= 54
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  54
# max EI found at x= [[1.32733532 1.8142256 ]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.35083961713279
# Enrichement current spent budget:  27.0  Total cost including DOE:  37.0
# ######################################
# iteration n= 55
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  55
# max EI found at x= [[ 0.99886358 -1.78836653]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.0
# Enrichement current spent budget:  27.5  Total cost including DOE:  37.5
# ######################################
# iteration n= 56
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  56
# max EI found at x= [[0.43549728 0.20284667]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.315169959131493
# Enrichement current spent budget:  28.0  Total cost including DOE:  38.0
# ######################################
# iteration n= 57
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  57
# max EI found at x= [[0.47796744 1.24207487]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.0
# Enrichement current spent budget:  28.5  Total cost including DOE:  38.5
# ######################################
# iteration n= 58
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  58
# max EI found at x= [[-1.17117283  1.3044803 ]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -1.4152378521823277
# Enrichement current spent budget:  29.0  Total cost including DOE:  39.0
# ######################################
# iteration n= 59
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  59
# max EI found at x= [[1.08522294 1.37159662]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -2.833138730129816
# Enrichement current spent budget:  29.5  Total cost including DOE:  39.5
# ######################################
# iteration n= 60
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  60
# max EI found at x= [[1.34273039 1.95263679]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -4.284710241636828
# Enrichement current spent budget:  30.0  Total cost including DOE:  40.0
# ######################################
# iteration n= 61
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  61
# max EI found at x= [[0.08232888 0.2050487 ]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -1.9512999769965642
# Enrichement current spent budget:  30.5  Total cost including DOE:  40.5
# ######################################
# iteration n= 62
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  62
# max EI found at x= [[-1.40353665  1.94621096]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.6023886639706013
# Enrichement current spent budget:  31.0  Total cost including DOE:  41.0
# ######################################
# iteration n= 63
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  63
# max EI found at x= [[1.21684426 1.26872875]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -2.0447282366925617
# Enrichement current spent budget:  31.5  Total cost including DOE:  41.5
# ######################################
# iteration n= 64
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  64
# max EI found at x= [[0.63449963 0.34185668]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.10729539240843
# Enrichement current spent budget:  32.0  Total cost including DOE:  42.0
# ######################################
# iteration n= 65
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  65
# max EI found at x= [[ 0.00199059 -0.13877081]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -3.7784809717238783
# Enrichement current spent budget:  32.5  Total cost including DOE:  42.5
# ######################################
# iteration n= 66
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  66
# max EI found at x= [[0.98813541 1.06033567]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -5.884235963583405
# Enrichement current spent budget:  33.0  Total cost including DOE:  43.0
# ######################################
# iteration n= 67
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  67
# max EI found at x= [[0.67339753 0.21691362]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.8970530117239957
# Enrichement current spent budget:  33.5  Total cost including DOE:  43.5
# ######################################
# iteration n= 68
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  68
# max EI found at x= [[-0.04181     0.22038901]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.8542427116939972
# Enrichement current spent budget:  34.0  Total cost including DOE:  44.0
# ######################################
# iteration n= 69
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  69
# max EI found at x= [[-0.50365406  0.14615266]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -3.2437370033072863
# Enrichement current spent budget:  34.5  Total cost including DOE:  44.5
# ######################################
# iteration n= 70
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  70
# max EI found at x= [[ 0.02578357 -0.07768589]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -5.136982163506543
# Enrichement current spent budget:  35.0  Total cost including DOE:  45.0
# ######################################
# iteration n= 71
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  71
# max EI found at x= [[1.81287582 1.21249077]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.0
# Enrichement current spent budget:  35.5  Total cost including DOE:  45.5
# ######################################
# iteration n= 72
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  72
# max EI found at x= [[0.31988951 0.24813675]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -4.088662326056989
# Enrichement current spent budget:  36.0  Total cost including DOE:  46.0
# ######################################
# iteration n= 73
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  73
# max EI found at x= [[-0.13095958 -1.08296889]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.0
# Enrichement current spent budget:  36.5  Total cost including DOE:  46.5
# ######################################
# iteration n= 74
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  74
# max EI found at x= [[0.49052123 0.17430237]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -5.932819474431012
# Enrichement current spent budget:  37.0  Total cost including DOE:  47.0
# ######################################
# iteration n= 75
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  75
# max EI found at x= [[1.04448835 0.90806779]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -3.2370900969685703
# Enrichement current spent budget:  37.5  Total cost including DOE:  47.5
# ######################################
# iteration n= 76
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  76
# max EI found at x= [[0.72937311 0.38359377]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -4.309100542140454
# Enrichement current spent budget:  38.0  Total cost including DOE:  48.0
# ######################################
# iteration n= 77
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  77
# max EI found at x= [[-0.80166808  0.73115498]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -2.5709245264763023
# Enrichement current spent budget:  38.5  Total cost including DOE:  48.5
# ######################################
# iteration n= 78
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  78
# max EI found at x= [[0.29134077 0.33683018]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -6.479347752958406e-22
# Enrichement current spent budget:  39.0  Total cost including DOE:  49.0
# ######################################
# iteration n= 79
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  79
# max EI found at x= [[1.07193476 1.04988238]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -5.5857632771026555
# Enrichement current spent budget:  39.5  Total cost including DOE:  49.5
# ######################################
# iteration n= 80
# Number of Hi Fi calls during optimization=  0
# Number of Low Fi calls during optimization=  80
# max EI found at x= [[ 0.04833526 -0.63897336]]
# Current best value= 6.652627267762126  distance to reference solution:  6.652627215678107
# value of the EI = -0.0
# Enrichement current spent budget:  40.0  Total cost including DOE:  50.0

# %%
# for the visualization
doe = doe_x
response = doe_y

doe_LF = []
doe_HF = []
response_LF = []
response_HF = []

doe_HF = doe[None]
doe_LF = doe[0]
response_HF = response[None]
response_LF = response[0]


num = 100
x = np.linspace(-2.0, 2.0, num)
y = np.linspace(-2.0, 2.0, num)
xv, yv = np.meshgrid(x, y)

x_test = np.array([np.ravel(xv), np.ravel(yv)]).T
z_HF = np.zeros([num * num, 1])
z_HF = Rosen_HF(x_test)
fig1 = plt.figure(figsize=(8, 6))
axSurrogate1 = fig1.add_subplot(111)
surf1 = axSurrogate1.contour(
    xv, yv, z_HF.reshape((num, num)), 150, cmap=cm.PiYG, antialiased=True, alpha=0.6
)

scatter2 = axSurrogate1.scatter(
    doe_LF.T[0][-2 * n :],
    doe_LF.T[1][-2 * n :],
    s=20.0,
    c="lightblue",
    label="Initial LF DOE",
)
scatter1 = axSurrogate1.scatter(
    doe_LF.T[0][0 : -2 * n],
    doe_LF.T[1][0 : -2 * n],
    s=20.0,
    c="orange",
    label="LF enriched points",
)
scatter2 = axSurrogate1.scatter(
    doe_HF.T[0][-n:], doe_HF.T[1][-n:], s=20.0, c="b", label="Initial HF DOE"
)
scatter2 = axSurrogate1.scatter(
    doe_HF.T[0][0:-n], doe_HF.T[1][0:-n], s=20.0, c="red", label="HF enriched points"
)
scatter3 = axSurrogate1.scatter(1, 1, s=30.0, c="C2", marker="x", label="True Optimum")
axSurrogate1.set_xlim([-2, 2])
axSurrogate1.set_ylim([-2, 2])
axSurrogate1.set_title(r"2D Rosenbrock Function", fontsize=12)
axSurrogate1.legend()
plt.show()
